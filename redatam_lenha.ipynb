# %%
import os, pandas as pd


lena=pd.read_excel(os.path.join("data","leña.xlsx"))

# %%
lena=lena.iloc[:,1:]
lena.head(20)
# Out:
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                       AREA # 010101
# 9                                                 NaN
# 10  H: La energía o combustible que utiliza para c...
# 11                                        No usa leña
# 12                                        Sí usa leña
# 13                                              Total
# 14                                                NaN
# 15                                      AREA # 010102
# 16                                                NaN
# 17  H: La energía o combustible que utiliza para c...
# 18                                        No usa leña
# 19                                        Sí usa leña
#
#                                       Unnamed: 2 Unnamed: 3   Unnamed: 4
# 0                                            NaN        NaN          NaN
# 1                                            NaN        NaN          NaN
# 2                                            NaN        NaN          NaN
# 3                                            NaN        NaN          NaN
# 4                                            NaN        NaN          NaN
# 5                                            NaN        NaN          NaN
# 6                                            NaN        NaN          NaN
# 7                                            NaN        NaN          NaN
# 8   Amazonas, Chachapoyas, distrito: Chachapoyas        NaN          NaN
# 9                                            NaN        NaN          NaN
# 10                                         Casos          %  Acumulado %
# 11                                          6301   0.753798     0.753798
# 12                                          2058   0.246202            1
# 13                                          8359          1            1
# 14                                           NaN        NaN          NaN
# 15     Amazonas, Chachapoyas, distrito: Asunción        NaN          NaN
# 16                                           NaN        NaN          NaN
# 17                                         Casos          %  Acumulado %
# 18                                             6   0.057692     0.057692
# 19                                            98   0.942308            1

# %%
lena=lena[~lena.isnull().all(axis=1)]

# %%
lena=lena[~lena.iloc[:,0].str.startswith('H:')]

# %%
lena=lena.loc[:13122,:]

# %%
lena.reset_index(drop=True,inplace=True)
lena
# Out:
#          Unnamed: 1                                    Unnamed: 2 Unnamed: 3  \
# 0     AREA # 010101  Amazonas, Chachapoyas, distrito: Chachapoyas        NaN
# 1       No usa leña                                          6301   0.753798
# 2       Sí usa leña                                          2058   0.246202
# 3             Total                                          8359          1
# 4     AREA # 010102     Amazonas, Chachapoyas, distrito: Asunción        NaN
# ...             ...                                           ...        ...
# 7488          Total                                          1295          1
# 7489  AREA # 250401               Ucayali, Purús, distrito: Purús        NaN
# 7490    No usa leña                                           178   0.258721
# 7491    Sí usa leña                                           510   0.741279
# 7492          Total                                           688          1
#
#      Unnamed: 4
# 0           NaN
# 1      0.753798
# 2             1
# 3             1
# 4           NaN
# ...         ...
# 7488          1
# 7489        NaN
# 7490   0.258721
# 7491          1
# 7492          1
#
# [7493 rows x 4 columns]

# %%
lena=lena[~(lena.iloc[:,0].str.startswith('No') | lena.iloc[:,0].str.startswith('To'))]

# %%
lena.reset_index(drop=True,inplace=True)

# %%
lena=lena.iloc[:,:-1]

# %%
lena['lenha_pct']=lena.iloc[:,2].shift(-1)
lena
# Out:
#          Unnamed: 1                                         Unnamed: 2  \
# 0     AREA # 010101       Amazonas, Chachapoyas, distrito: Chachapoyas
# 1       Sí usa leña                                               2058
# 2     AREA # 010102          Amazonas, Chachapoyas, distrito: Asunción
# 3       Sí usa leña                                                 98
# 4     AREA # 010103            Amazonas, Chachapoyas, distrito: Balsas
# ...             ...                                                ...
# 3741    Sí usa leña                                                977
# 3742  AREA # 250305  Ucayali, Padre Abad, distrito: Alexander Von H...
# 3743    Sí usa leña                                                662
# 3744  AREA # 250401                    Ucayali, Purús, distrito: Purús
# 3745    Sí usa leña                                                510
#
#      Unnamed: 3 lenha_pct
# 0           NaN  0.246202
# 1      0.246202       NaN
# 2           NaN  0.942308
# 3      0.942308       NaN
# 4           NaN  0.853521
# ...         ...       ...
# 3741   0.507532       NaN
# 3742        NaN  0.511197
# 3743   0.511197       NaN
# 3744        NaN  0.741279
# 3745   0.741279      None
#
# [3746 rows x 4 columns]

# %%
lena=lena.iloc[:,[0,1,3]]
lena
# Out:
#          Unnamed: 1                                         Unnamed: 2  \
# 0     AREA # 010101       Amazonas, Chachapoyas, distrito: Chachapoyas
# 1       Sí usa leña                                               2058
# 2     AREA # 010102          Amazonas, Chachapoyas, distrito: Asunción
# 3       Sí usa leña                                                 98
# 4     AREA # 010103            Amazonas, Chachapoyas, distrito: Balsas
# ...             ...                                                ...
# 3741    Sí usa leña                                                977
# 3742  AREA # 250305  Ucayali, Padre Abad, distrito: Alexander Von H...
# 3743    Sí usa leña                                                662
# 3744  AREA # 250401                    Ucayali, Purús, distrito: Purús
# 3745    Sí usa leña                                                510
#
#      lenha_pct
# 0     0.246202
# 1          NaN
# 2     0.942308
# 3          NaN
# 4     0.853521
# ...        ...
# 3741       NaN
# 3742  0.511197
# 3743       NaN
# 3744  0.741279
# 3745      None
#
# [3746 rows x 3 columns]

# %%
lena=lena[~(lena.iloc[:,0].str.startswith('Sí'))].reset_index(drop=True)
lena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  1874 non-null   object
#  1   Unnamed: 2  1874 non-null   object
#  2   lenha_pct   1872 non-null   object
# dtypes: object(3)
# memory usage: 44.0+ KB

# %%
lena[lena.isnull().any(axis=1)]
# Out:
#          Unnamed: 1                                         Unnamed: 2  \
# 693   AREA # 070105  Prov. Constitucional del Callao, distrito: La ...
# 1295  AREA # 150116                        Lima, Lima, distrito: Lince
#
#      lenha_pct
# 693        NaN
# 1295       NaN

# %%
lena['lenha_pct']=lena.lenha_pct.fillna(0)
lena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  1874 non-null   object
#  1   Unnamed: 2  1874 non-null   object
#  2   lenha_pct   1874 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 44.0+ KB

# %%
lena.iloc[0::2,1]
# Out:
# 0            Amazonas, Chachapoyas, distrito: Chachapoyas
# 2                 Amazonas, Chachapoyas, distrito: Balsas
# 4              Amazonas, Chachapoyas, distrito: Chiliquin
# 6                Amazonas, Chachapoyas, distrito: Granada
# 8               Amazonas, Chachapoyas, distrito: La Jalca
#                               ...
# 1864                 Ucayali, Atalaya, distrito: Raymondi
# 1866                 Ucayali, Atalaya, distrito: Tahuania
# 1868            Ucayali, Padre Abad, distrito: Padre Abad
# 1870              Ucayali, Padre Abad, distrito: Curimana
# 1872    Ucayali, Padre Abad, distrito: Alexander Von H...
# Name: Unnamed: 2, Length: 937, dtype: object

# %%
lena['code']=lena.iloc[:,0].str.split(r'# ',expand=True).iloc[:,1]
lena=lena.iloc[:,1:]
lena
# Out:
#                                              Unnamed: 2  lenha_pct    code
# 0          Amazonas, Chachapoyas, distrito: Chachapoyas   0.246202  010101
# 1             Amazonas, Chachapoyas, distrito: Asunción   0.942308  010102
# 2               Amazonas, Chachapoyas, distrito: Balsas   0.853521  010103
# 3                Amazonas, Chachapoyas, distrito: Cheto   0.818182  010104
# 4            Amazonas, Chachapoyas, distrito: Chiliquin   0.956311  010105
# ...                                                 ...        ...     ...
# 1869             Ucayali, Padre Abad, distrito: Irazola   0.545455  250302
# 1870            Ucayali, Padre Abad, distrito: Curimana   0.726645  250303
# 1871             Ucayali, Padre Abad, distrito: Neshuya   0.507532  250304
# 1872  Ucayali, Padre Abad, distrito: Alexander Von H...   0.511197  250305
# 1873                    Ucayali, Purús, distrito: Purús   0.741279  250401
#
# [1874 rows x 3 columns]

# %%
lena[lena.iloc[:,0].str.contains('allao')].iloc[:,0]
# Out:
# 689    Prov. Constitucional del Callao, distrito: Callao
# 690    Prov. Constitucional del Callao, distrito: Bel...
# 691    Prov. Constitucional del Callao, distrito: Car...
# 692    Prov. Constitucional del Callao, distrito: La ...
# 693    Prov. Constitucional del Callao, distrito: La ...
# 694    Prov. Constitucional del Callao, distrito: Ven...
# 695    Prov. Constitucional del Callao, distrito: Mi ...
# Name: Unnamed: 2, dtype: object

# %%
callao1='Prov. Constitucional del Callao, '
callao2='Prov. Constitucional del Callao, Prov. Constitucional del Callao, '

# %%
lena.iloc[:,0]=lena.iloc[:,0].str.replace(callao1,callao2, regex=False)

# %%
lena.iloc[:,0].str.split(r'distrito:|,',expand=True).iloc[:,[0,1,3]]
# Out:
#              0             1                        3
# 0     Amazonas   Chachapoyas              Chachapoyas
# 1     Amazonas   Chachapoyas                 Asunción
# 2     Amazonas   Chachapoyas                   Balsas
# 3     Amazonas   Chachapoyas                    Cheto
# 4     Amazonas   Chachapoyas                Chiliquin
# ...        ...           ...                      ...
# 1869   Ucayali    Padre Abad                  Irazola
# 1870   Ucayali    Padre Abad                 Curimana
# 1871   Ucayali    Padre Abad                  Neshuya
# 1872   Ucayali    Padre Abad   Alexander Von Humboldt
# 1873   Ucayali         Purús                    Purús
#
# [1874 rows x 3 columns]

# %%
lena=pd.concat([lena.iloc[:,0].str.split(r'distrito:|,',expand=True).iloc[:,[0,1,3]],lena.iloc[:,1:]],axis=1)
lena
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 lena=pd.concat([lena.iloc[:,0].str.split(r'distrito:|,',expand=True).iloc[:,[0,1,3]],lena.iloc[:,1:]],axis=1)
#       2 lena
#
# File ~/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/pandas/core/indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/pandas/core/indexing.py:1481, in _iLocIndexer._validate_key(self, key, axis)
#    1479     # check that the key does not exceed the maximum size of the index
#    1480     if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1481         raise IndexError("positional indexers are out-of-bounds")
#    1482 else:
#    1483     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %%
lena.columns=['Departamento','Provincia','Distrito','lenha_pct','code']

# %%
lena.loc[:,:'Distrito']=lena.loc[:,:'Distrito'].apply(lambda x:x.str.strip())

# %%
lena[lena.Provincia.str.contains('allao')]
# Out:
#                         Departamento                        Provincia  \
# 689  Prov. Constitucional del Callao  Prov. Constitucional del Callao
# 690  Prov. Constitucional del Callao  Prov. Constitucional del Callao
# 691  Prov. Constitucional del Callao  Prov. Constitucional del Callao
# 692  Prov. Constitucional del Callao  Prov. Constitucional del Callao
# 693  Prov. Constitucional del Callao  Prov. Constitucional del Callao
# 694  Prov. Constitucional del Callao  Prov. Constitucional del Callao
# 695  Prov. Constitucional del Callao  Prov. Constitucional del Callao
#
#                        Distrito  lenha_pct    code
# 689                      Callao   0.003671  070101
# 690                  Bellavista   0.000296  070102
# 691  Carmen de la Legua Reynoso   0.001389  070103
# 692                    La Perla   0.000397  070104
# 693                    La Punta   0.000000  070105
# 694                  Ventanilla   0.058954  070106
# 695                     Mi Perú   0.029458  070107

# %%
lena.replace({'Prov. Constitucional del Callao':'Callao'},inplace=True)

# %%
lena['key']=lena.Departamento+lena.Provincia+lena.Distrito

# %%
lena.key=lena.key.str.upper()

# %%
lena.key=lena.key.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
lena[lena.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Departamento, Provincia, Distrito, lenha_pct, code, key]
# Index: []

# %%
lena
# Out:
#      Departamento    Provincia                Distrito  lenha_pct    code  \
# 0        Amazonas  Chachapoyas             Chachapoyas   0.246202  010101
# 1        Amazonas  Chachapoyas                Asunción   0.942308  010102
# 2        Amazonas  Chachapoyas                  Balsas   0.853521  010103
# 3        Amazonas  Chachapoyas                   Cheto   0.818182  010104
# 4        Amazonas  Chachapoyas               Chiliquin   0.956311  010105
# ...           ...          ...                     ...        ...     ...
# 1869      Ucayali   Padre Abad                 Irazola   0.545455  250302
# 1870      Ucayali   Padre Abad                Curimana   0.726645  250303
# 1871      Ucayali   Padre Abad                 Neshuya   0.507532  250304
# 1872      Ucayali   Padre Abad  Alexander Von Humboldt   0.511197  250305
# 1873      Ucayali        Purús                   Purús   0.741279  250401
#
#                                           key
# 0              AMAZONASCHACHAPOYASCHACHAPOYAS
# 1                 AMAZONASCHACHAPOYASASUNCION
# 2                   AMAZONASCHACHAPOYASBALSAS
# 3                    AMAZONASCHACHAPOYASCHETO
# 4                AMAZONASCHACHAPOYASCHILIQUIN
# ...                                       ...
# 1869                 UCAYALIPADRE ABADIRAZOLA
# 1870                UCAYALIPADRE ABADCURIMANA
# 1871                 UCAYALIPADRE ABADNESHUYA
# 1872  UCAYALIPADRE ABADALEXANDER VON HUMBOLDT
# 1873                        UCAYALIPURUSPURUS
#
# [1874 rows x 6 columns]

# %%
import geopandas as gpd

distmap=gpd.read_file(os.path.join("maps","peru_shp_distritos1874","DISTRITOS1874.SHP"))

# %%
distmap
# Out:
#      DEPARTAMEN PROVINCIA                              DISTRITO INSTITUCIO  \
# 0         TACNA     TACNA  CORONEL GREGORIO ALBARRACIN LANCHIPA        IGN
# 1         TACNA     TACNA                              POCOLLAY        IGN
# 2         TACNA     TACNA                                CALANA        IGN
# 3         TACNA     TACNA                                 TACNA        IGN
# 4         TACNA     TACNA                                  SAMA        IGN
# ...         ...       ...                                   ...        ...
# 1869       LIMA      LIMA                           CIENEGUILLA        IGN
# 1870       LIMA      LIMA                                 ANCON        IGN
# 1871       LIMA      LIMA                            CARABAYLLO        IGN
# 1872     CALLAO    CALLAO                               MI PERU        IGN
# 1873       LIMA      LIMA                     SANTIAGO DE SURCO        IGN
#
#                                                geometry
# 0     POLYGON ((-70.17413 -18.12896, -70.17461 -18.1...
# 1     POLYGON ((-69.93475 -17.92557, -69.90467 -17.9...
# 2     POLYGON ((-70.11604 -17.91106, -70.11457 -17.9...
# 3     POLYGON ((-70.31490 -17.94498, -70.30682 -17.9...
# 4     POLYGON ((-70.42497 -17.88934, -70.48022 -17.9...
# ...                                                 ...
# 1869  POLYGON ((-76.72917 -11.99948, -76.72596 -11.9...
# 1870  POLYGON ((-77.06501 -11.57523, -77.06499 -11.5...
# 1871  POLYGON ((-76.89892 -11.72963, -76.89768 -11.7...
# 1872  POLYGON ((-77.11491 -11.84189, -77.11450 -11.8...
# 1873  POLYGON ((-76.95742 -12.07604, -76.95741 -12.0...
#
# [1874 rows x 5 columns]

# %%
distmap['key']=distmap.DEPARTAMEN+distmap.PROVINCIA+distmap.DISTRITO

# %%
distmap['key']=distmap.key.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
distmap.key=distmap.key.str.upper().str.strip()
distmap.key=distmap.key.str.replace(r'  ',' ',regex=True)

# %%
distmap.merge(lena, on='key', how='outer')
# Out:
#      DEPARTAMEN PROVINCIA                              DISTRITO INSTITUCIO  \
# 0         TACNA     TACNA  CORONEL GREGORIO ALBARRACIN LANCHIPA        IGN
# 1         TACNA     TACNA                              POCOLLAY        IGN
# 2         TACNA     TACNA                                CALANA        IGN
# 3         TACNA     TACNA                                 TACNA        IGN
# 4         TACNA     TACNA                                  SAMA        IGN
# ...         ...       ...                                   ...        ...
# 1898        NaN       NaN                                   NaN        NaN
# 1899        NaN       NaN                                   NaN        NaN
# 1900        NaN       NaN                                   NaN        NaN
# 1901        NaN       NaN                                   NaN        NaN
# 1902        NaN       NaN                                   NaN        NaN
#
#                                                geometry  \
# 0     POLYGON ((-70.17413 -18.12896, -70.17461 -18.1...
# 1     POLYGON ((-69.93475 -17.92557, -69.90467 -17.9...
# 2     POLYGON ((-70.11604 -17.91106, -70.11457 -17.9...
# 3     POLYGON ((-70.31490 -17.94498, -70.30682 -17.9...
# 4     POLYGON ((-70.42497 -17.88934, -70.48022 -17.9...
# ...                                                 ...
# 1898                                               None
# 1899                                               None
# 1900                                               None
# 1901                                               None
# 1902                                               None
#
#                                                  key Departamento   Provincia  \
# 0     TACNATACNACORONEL GREGORIO ALBARRACIN LANCHIPA        Tacna       Tacna
# 1                                 TACNATACNAPOCOLLAY        Tacna       Tacna
# 2                                   TACNATACNACALANA        Tacna       Tacna
# 3                                    TACNATACNATACNA        Tacna       Tacna
# 4                                     TACNATACNASAMA        Tacna       Tacna
# ...                                              ...          ...         ...
# 1898                               LIMAYAUYOSALLAUCA         Lima      Yauyos
# 1899                   PIURASECHURARINCONADA LLICUAR        Piura     Sechura
# 1900                     SAN MARTINPICOTATRES UNIDOS   San Martín      Picota
# 1901                   SAN MARTINSAN MARTINPAPAPLAYA   San Martín  San Martín
# 1902                        TACNATARATAESTIQUE-PAMPA        Tacna      Tarata
#
#                                   Distrito  lenha_pct    code
# 0     Coronel Gregorio Albarracin Lanchipa   0.090590  230110
# 1                                 Pocollay   0.124197  230108
# 2                                   Calana   0.566914  230103
# 3                                    Tacna   0.052440  230101
# 4                                     Sama   0.427014  230109
# ...                                    ...        ...     ...
# 1898                               Allauca   0.855696  151003
# 1899                     Rinconada Llicuar   0.510490  200806
# 1900                           Tres Unidos   0.865419  220710
# 1901                             Papaplaya   0.877477  220911
# 1902                         Estique-Pampa   0.938272  230404
#
# [1903 rows x 11 columns]

# %%
onlyMap=set(distmap.key)-set(lena.key)
onlyMap
# Out:
# {'APURIMACAYMARAESCARAIBAMBA',
#  'APURIMACCHINCHEROSANCO HUALLO',
#  'AYACUCHOVICTOR FAJARDOHUAYA',
#  'AYACUCHOVILCAS-HUAMANACCOMARCA',
#  'AYACUCHOVILCAS-HUAMANCARHUANCA',
#  'AYACUCHOVILCAS-HUAMANCONCEPCION',
#  'AYACUCHOVILCAS-HUAMANHUAMBALPA',
#  'AYACUCHOVILCAS-HUAMANINDEPENDENCIA',
#  'AYACUCHOVILCAS-HUAMANSAURAMA',
#  'AYACUCHOVILCAS-HUAMANVILCAS HUAMAN',
#  'AYACUCHOVILCAS-HUAMANVISCHONGO',
#  'HUANCAVELICAANGARAESHUALLAY GRANDE',
#  'HUANCAVELICAANGARAESHUANCA HUANCA',
#  'HUANUCOHUANUCOQUISQUI',
#  'ICANAZCACHANGUILLO',
#  'ICANAZCAEL INGENIO',
#  'ICANAZCAMARCONA',
#  'ICANAZCANAZCA',
#  'ICANAZCAVISTA ALEGRE',
#  'JUNINCHUPACASAN JUAN DE YSCOS',
#  'JUNINJAUJAMASMA-CHICCHE',
#  'JUNINJAUJATUNAN-MARCA',
#  'LIMAHUAROCHIRILARAOS',
#  'LIMALIMAMAGDALENA VIEJA',
#  'LIMAYAUYOSAYAUCA',
#  'PIURASECHURARINCONADA-LLICUAR',
#  'SAN MARTINPICOTATRES-UNIDOS',
#  'SAN MARTINSAN MARTINPAPA-PLAYA',
#  'TACNATARATAESTIQUE PAMPA'}

# %%
onlyLena=set(lena.key)-set(distmap.key)
onlyLena
# Out:
# {'APURIMACAYMARAESCARAYBAMBA',
#  'APURIMACCHINCHEROSANCO_HUALLO',
#  'AYACUCHOVICTOR FAJARDOHUALLA',
#  'AYACUCHOVILCAS HUAMANACCOMARCA',
#  'AYACUCHOVILCAS HUAMANCARHUANCA',
#  'AYACUCHOVILCAS HUAMANCONCEPCION',
#  'AYACUCHOVILCAS HUAMANHUAMBALPA',
#  'AYACUCHOVILCAS HUAMANINDEPENDENCIA',
#  'AYACUCHOVILCAS HUAMANSAURAMA',
#  'AYACUCHOVILCAS HUAMANVILCAS HUAMAN',
#  'AYACUCHOVILCAS HUAMANVISCHONGO',
#  'HUANCAVELICAANGARAESHUANCA-HUANCA',
#  'HUANCAVELICAANGARAESHUAYLLAY GRANDE',
#  'HUANUCOHUANUCOQUISQUI (KICHKI)',
#  'ICANASCACHANGUILLO',
#  'ICANASCAEL INGENIO',
#  'ICANASCAMARCONA',
#  'ICANASCANASCA',
#  'ICANASCAVISTA ALEGRE',
#  'JUNINCHUPACASAN JUAN DE ISCOS',
#  'JUNINJAUJAMASMA CHICCHE',
#  'JUNINJAUJATUNAN MARCA',
#  'LIMAHUAROCHIRISAN PEDRO DE LARAOS',
#  'LIMALIMAPUEBLO LIBRE',
#  'LIMAYAUYOSALLAUCA',
#  'PIURASECHURARINCONADA LLICUAR',
#  'SAN MARTINPICOTATRES UNIDOS',
#  'SAN MARTINSAN MARTINPAPAPLAYA',
#  'TACNATARATAESTIQUE-PAMPA'}

# %%
from thefuzz import process as fz

# take a country from OnlyFragile
# look for a country in OnlyCia and return the most similar
[(l,fz.extractOne(l, onlyMap)) for l in sorted(onlyLena)]
# Out:
# [('APURIMACAYMARAESCARAYBAMBA', ('APURIMACAYMARAESCARAIBAMBA', 96)),
#  ('APURIMACCHINCHEROSANCO_HUALLO', ('APURIMACCHINCHEROSANCO HUALLO', 97)),
#  ('AYACUCHOVICTOR FAJARDOHUALLA', ('AYACUCHOVICTOR FAJARDOHUAYA', 95)),
#  ('AYACUCHOVILCAS HUAMANACCOMARCA', ('AYACUCHOVILCAS-HUAMANACCOMARCA', 100)),
#  ('AYACUCHOVILCAS HUAMANCARHUANCA', ('AYACUCHOVILCAS-HUAMANCARHUANCA', 100)),
#  ('AYACUCHOVILCAS HUAMANCONCEPCION', ('AYACUCHOVILCAS-HUAMANCONCEPCION', 100)),
#  ('AYACUCHOVILCAS HUAMANHUAMBALPA', ('AYACUCHOVILCAS-HUAMANHUAMBALPA', 100)),
#  ('AYACUCHOVILCAS HUAMANINDEPENDENCIA',
#   ('AYACUCHOVILCAS-HUAMANINDEPENDENCIA', 100)),
#  ('AYACUCHOVILCAS HUAMANSAURAMA', ('AYACUCHOVILCAS-HUAMANSAURAMA', 100)),
#  ('AYACUCHOVILCAS HUAMANVILCAS HUAMAN',
#   ('AYACUCHOVILCAS-HUAMANVILCAS HUAMAN', 100)),
#  ('AYACUCHOVILCAS HUAMANVISCHONGO', ('AYACUCHOVILCAS-HUAMANVISCHONGO', 100)),
#  ('HUANCAVELICAANGARAESHUANCA-HUANCA',
#   ('HUANCAVELICAANGARAESHUANCA HUANCA', 100)),
#  ('HUANCAVELICAANGARAESHUAYLLAY GRANDE',
#   ('HUANCAVELICAANGARAESHUALLAY GRANDE', 99)),
#  ('HUANUCOHUANUCOQUISQUI (KICHKI)', ('HUANUCOHUANUCOQUISQUI', 95)),
#  ('ICANASCACHANGUILLO', ('ICANAZCACHANGUILLO', 94)),
#  ('ICANASCAEL INGENIO', ('ICANAZCAEL INGENIO', 94)),
#  ('ICANASCAMARCONA', ('ICANAZCAMARCONA', 93)),
#  ('ICANASCANASCA', ('ICANAZCANAZCA', 85)),
#  ('ICANASCAVISTA ALEGRE', ('ICANAZCAVISTA ALEGRE', 95)),
#  ('JUNINCHUPACASAN JUAN DE ISCOS', ('JUNINCHUPACASAN JUAN DE YSCOS', 97)),
#  ('JUNINJAUJAMASMA CHICCHE', ('JUNINJAUJAMASMA-CHICCHE', 100)),
#  ('JUNINJAUJATUNAN MARCA', ('JUNINJAUJATUNAN-MARCA', 100)),
#  ('LIMAHUAROCHIRISAN PEDRO DE LARAOS', ('LIMAHUAROCHIRILARAOS', 75)),
#  ('LIMALIMAPUEBLO LIBRE', ('LIMALIMAMAGDALENA VIEJA', 56)),
#  ('LIMAYAUYOSALLAUCA', ('LIMAYAUYOSAYAUCA', 91)),
#  ('PIURASECHURARINCONADA LLICUAR', ('PIURASECHURARINCONADA-LLICUAR', 100)),
#  ('SAN MARTINPICOTATRES UNIDOS', ('SAN MARTINPICOTATRES-UNIDOS', 100)),
#  ('SAN MARTINSAN MARTINPAPAPLAYA', ('SAN MARTINSAN MARTINPAPA-PLAYA', 98)),
#  ('TACNATARATAESTIQUE-PAMPA', ('TACNATARATAESTIQUE PAMPA', 100))]

# %%
changesLena1={l:fz.extractOne(l, onlyMap)[0] 
                 for l in sorted(onlyLena)}
#dict of matches
changesLena1
# Out:
# {'APURIMACAYMARAESCARAYBAMBA': 'APURIMACAYMARAESCARAIBAMBA',
#  'APURIMACCHINCHEROSANCO_HUALLO': 'APURIMACCHINCHEROSANCO HUALLO',
#  'AYACUCHOVICTOR FAJARDOHUALLA': 'AYACUCHOVICTOR FAJARDOHUAYA',
#  'AYACUCHOVILCAS HUAMANACCOMARCA': 'AYACUCHOVILCAS-HUAMANACCOMARCA',
#  'AYACUCHOVILCAS HUAMANCARHUANCA': 'AYACUCHOVILCAS-HUAMANCARHUANCA',
#  'AYACUCHOVILCAS HUAMANCONCEPCION': 'AYACUCHOVILCAS-HUAMANCONCEPCION',
#  'AYACUCHOVILCAS HUAMANHUAMBALPA': 'AYACUCHOVILCAS-HUAMANHUAMBALPA',
#  'AYACUCHOVILCAS HUAMANINDEPENDENCIA': 'AYACUCHOVILCAS-HUAMANINDEPENDENCIA',
#  'AYACUCHOVILCAS HUAMANSAURAMA': 'AYACUCHOVILCAS-HUAMANSAURAMA',
#  'AYACUCHOVILCAS HUAMANVILCAS HUAMAN': 'AYACUCHOVILCAS-HUAMANVILCAS HUAMAN',
#  'AYACUCHOVILCAS HUAMANVISCHONGO': 'AYACUCHOVILCAS-HUAMANVISCHONGO',
#  'HUANCAVELICAANGARAESHUANCA-HUANCA': 'HUANCAVELICAANGARAESHUANCA HUANCA',
#  'HUANCAVELICAANGARAESHUAYLLAY GRANDE': 'HUANCAVELICAANGARAESHUALLAY GRANDE',
#  'HUANUCOHUANUCOQUISQUI (KICHKI)': 'HUANUCOHUANUCOQUISQUI',
#  'ICANASCACHANGUILLO': 'ICANAZCACHANGUILLO',
#  'ICANASCAEL INGENIO': 'ICANAZCAEL INGENIO',
#  'ICANASCAMARCONA': 'ICANAZCAMARCONA',
#  'ICANASCANASCA': 'ICANAZCANAZCA',
#  'ICANASCAVISTA ALEGRE': 'ICANAZCAVISTA ALEGRE',
#  'JUNINCHUPACASAN JUAN DE ISCOS': 'JUNINCHUPACASAN JUAN DE YSCOS',
#  'JUNINJAUJAMASMA CHICCHE': 'JUNINJAUJAMASMA-CHICCHE',
#  'JUNINJAUJATUNAN MARCA': 'JUNINJAUJATUNAN-MARCA',
#  'LIMAHUAROCHIRISAN PEDRO DE LARAOS': 'LIMAHUAROCHIRILARAOS',
#  'LIMALIMAPUEBLO LIBRE': 'LIMALIMAMAGDALENA VIEJA',
#  'LIMAYAUYOSALLAUCA': 'LIMAYAUYOSAYAUCA',
#  'PIURASECHURARINCONADA LLICUAR': 'PIURASECHURARINCONADA-LLICUAR',
#  'SAN MARTINPICOTATRES UNIDOS': 'SAN MARTINPICOTATRES-UNIDOS',
#  'SAN MARTINSAN MARTINPAPAPLAYA': 'SAN MARTINSAN MARTINPAPA-PLAYA',
#  'TACNATARATAESTIQUE-PAMPA': 'TACNATARATAESTIQUE PAMPA'}

# %%
lena.key.replace(to_replace=changesLena1,inplace=True)

# %%
lena
# Out:
#      Departamento    Provincia                Distrito  lenha_pct    code  \
# 0        Amazonas  Chachapoyas             Chachapoyas   0.246202  010101
# 1        Amazonas  Chachapoyas                Asunción   0.942308  010102
# 2        Amazonas  Chachapoyas                  Balsas   0.853521  010103
# 3        Amazonas  Chachapoyas                   Cheto   0.818182  010104
# 4        Amazonas  Chachapoyas               Chiliquin   0.956311  010105
# ...           ...          ...                     ...        ...     ...
# 1869      Ucayali   Padre Abad                 Irazola   0.545455  250302
# 1870      Ucayali   Padre Abad                Curimana   0.726645  250303
# 1871      Ucayali   Padre Abad                 Neshuya   0.507532  250304
# 1872      Ucayali   Padre Abad  Alexander Von Humboldt   0.511197  250305
# 1873      Ucayali        Purús                   Purús   0.741279  250401
#
#                                           key
# 0              AMAZONASCHACHAPOYASCHACHAPOYAS
# 1                 AMAZONASCHACHAPOYASASUNCION
# 2                   AMAZONASCHACHAPOYASBALSAS
# 3                    AMAZONASCHACHAPOYASCHETO
# 4                AMAZONASCHACHAPOYASCHILIQUIN
# ...                                       ...
# 1869                 UCAYALIPADRE ABADIRAZOLA
# 1870                UCAYALIPADRE ABADCURIMANA
# 1871                 UCAYALIPADRE ABADNESHUYA
# 1872  UCAYALIPADRE ABADALEXANDER VON HUMBOLDT
# 1873                        UCAYALIPURUSPURUS
#
# [1874 rows x 6 columns]

# %%
lenaMap=distmap.merge(lena, on='key').loc[:,['key','DEPARTAMEN','PROVINCIA','DISTRITO','lenha_pct','geometry']]
lenaMap
# Out:
#                                                  key DEPARTAMEN PROVINCIA  \
# 0     TACNATACNACORONEL GREGORIO ALBARRACIN LANCHIPA      TACNA     TACNA
# 1                                 TACNATACNAPOCOLLAY      TACNA     TACNA
# 2                                   TACNATACNACALANA      TACNA     TACNA
# 3                                    TACNATACNATACNA      TACNA     TACNA
# 4                                     TACNATACNASAMA      TACNA     TACNA
# ...                                              ...        ...       ...
# 1869                             LIMALIMACIENEGUILLA       LIMA      LIMA
# 1870                                   LIMALIMAANCON       LIMA      LIMA
# 1871                              LIMALIMACARABAYLLO       LIMA      LIMA
# 1872                             CALLAOCALLAOMI PERU     CALLAO    CALLAO
# 1873                       LIMALIMASANTIAGO DE SURCO       LIMA      LIMA
#
#                                   DISTRITO  lenha_pct  \
# 0     CORONEL GREGORIO ALBARRACIN LANCHIPA   0.090590
# 1                                 POCOLLAY   0.124197
# 2                                   CALANA   0.566914
# 3                                    TACNA   0.052440
# 4                                     SAMA   0.427014
# ...                                    ...        ...
# 1869                           CIENEGUILLA   0.134573
# 1870                                 ANCON   0.070872
# 1871                            CARABAYLLO   0.050134
# 1872                               MI PERU   0.029458
# 1873                     SANTIAGO DE SURCO   0.000994
#
#                                                geometry
# 0     POLYGON ((-70.17413 -18.12896, -70.17461 -18.1...
# 1     POLYGON ((-69.93475 -17.92557, -69.90467 -17.9...
# 2     POLYGON ((-70.11604 -17.91106, -70.11457 -17.9...
# 3     POLYGON ((-70.31490 -17.94498, -70.30682 -17.9...
# 4     POLYGON ((-70.42497 -17.88934, -70.48022 -17.9...
# ...                                                 ...
# 1869  POLYGON ((-76.72917 -11.99948, -76.72596 -11.9...
# 1870  POLYGON ((-77.06501 -11.57523, -77.06499 -11.5...
# 1871  POLYGON ((-76.89892 -11.72963, -76.89768 -11.7...
# 1872  POLYGON ((-77.11491 -11.84189, -77.11450 -11.8...
# 1873  POLYGON ((-76.95742 -12.07604, -76.95741 -12.0...
#
# [1874 rows x 6 columns]

# %%
distmap.to_file(os.path.join("maps","distritosPeru.gpkg"), layer='polygons', driver="GPKG")
lenaMap.to_file(os.path.join("maps","distritosPeru.gpkg"), layer='lenha', driver="GPKG")
