# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>
#
# _____
#
# <a id='home'></a>
#
# # Merging

# %% [markdown]
# Merging data sets need the following considerations:
#
# * Merging is done on two data frames.
# * You need a column in each data frame that share the same exact and unique values. The column names or titles need not be the same.
# * The merged table shows by default the mutual coincidences; but you can also request the values not matched, which will help you detect possible extra cleaning.
# * Pandas jargon uses a **left** and a **right** data frame: **left**.merge(**right**).
#
# At this stage, let me use other data frames we prepared previously:

# %%
import pandas as pd

co2Link='https://github.com/CienciaDeDatosEspacial/dataSets/raw/main/co2.csv'
co2=pd.read_csv(co2Link)

# %% [markdown]
# Remember the amount of rows:

# %%
co2.shape
# Out:
# (218, 4)

# %% [markdown]
# Also keep in mind the column names:

# %%
co2.columns
# Out:
# Index(['name', 'co2', 'co2_date', 'region'], dtype='object')

# %% [markdown]
# Now, take a look:

# %%
co2
# Out:
#                                               name           co2  co2_date  \
# 0                                            CHINA  1.077325e+10      2019
# 1                                    UNITED STATES  5.144361e+09      2019
# 2                                            INDIA  2.314738e+09      2019
# 3                                           RUSSIA  1.848070e+09      2019
# 4                                            JAPAN  1.103234e+09      2019
# ..                                             ...           ...       ...
# 213                                     ANTARCTICA  2.800000e+04      2019
# 214  SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA  1.300000e+04      2019
# 215                                           NIUE  8.000000e+03      2019
# 216                       NORTHERN MARIANA ISLANDS  0.000000e+00      2019
# 217                                         TUVALU  0.000000e+00      2019
#
#                       region
# 0    EAST AND SOUTHEAST ASIA
# 1              NORTH AMERICA
# 2                 SOUTH ASIA
# 3               CENTRAL ASIA
# 4    EAST AND SOUTHEAST ASIA
# ..                       ...
# 213               ANTARCTICA
# 214                   AFRICA
# 215    AUSTRALIA AND OCEANIA
# 216    AUSTRALIA AND OCEANIA
# 217    AUSTRALIA AND OCEANIA
#
# [218 rows x 4 columns]

# %% [markdown]
# Let me show this table:

# %%
isoLink='https://github.com/CienciaDeDatosEspacial/dataSets/raw/main/isodata.csv'
isoCodes=pd.read_csv(isoLink)
isoCodes
# Out:
#            Countryname                               Officialstatename  \
# 0          Afghanistan             The Islamic Republic of Afghanistan
# 1        Åland Islands                                           Åland
# 2              Albania                         The Republic of Albania
# 3              Algeria     The People's Democratic Republic of Algeria
# 4       American Samoa                 The Territory of American Samoa
# ..                 ...                                             ...
# 244  Wallis and Futuna  The Territory of the Wallis and Futuna Islands
# 245     Western Sahara            The Sahrawi Arab Democratic Republic
# 246              Yemen                           The Republic of Yemen
# 247             Zambia                          The Republic of Zambia
# 248           Zimbabwe                        The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .ax   AX  ALA
# 2             .al   AL  ALB
# 3             .dz   DZ  DZA
# 4             .as   AS  ASM
# ..            ...  ...  ...
# 244           .wf   WF  WLF
# 245           NaN   EH  ESH
# 246           .ye   YE  YEM
# 247           .zm   ZM  ZMB
# 248           .zw   ZW  ZWE
#
# [249 rows x 5 columns]

# %% [markdown]
# Merging is a key process for producing analytics. So, it is always good to add some column with a universal key. In this case, we should add the **ISO** columns to data frame. Notice that the isoCodes data frame has the countrynames in title case, so we need to set them to upper case:

# %%
isoCodes['Countryname']=isoCodes.Countryname.str.upper()

# %% [markdown]
# Notice the amount of rows before merging:

# %%
co2.shape[0], isoCodes.shape[0]
# Out:
# (218, 249)

# %% [markdown]
# Let me show you some merge approaches, but I will only show the amount of columns produced:
#
# 1. You keep only what is common in both key columns:
#
# This is the default. The final rows will be the ones where the key values in each data frame match exactly. In this case, your count of rows will be at most the amount of rows of the smallest data frame.

# %%
# how many resulting rows after inner merging
co2.merge(isoCodes,how='inner',left_on='name',right_on='Countryname')
# Out:
#            name           co2  co2_date                             region  \
# 0         CHINA  1.077325e+10      2019            EAST AND SOUTHEAST ASIA
# 1         INDIA  2.314738e+09      2019                         SOUTH ASIA
# 2         JAPAN  1.103234e+09      2019            EAST AND SOUTHEAST ASIA
# 3       GERMANY  7.268810e+08      2019                             EUROPE
# 4        CANADA  6.120840e+08      2019                      NORTH AMERICA
# ..          ...           ...       ...                                ...
# 167       NAURU  6.600000e+04      2019              AUSTRALIA AND OCEANIA
# 168  MONTSERRAT  3.300000e+04      2019  CENTRAL AMERICA AND THE CARIBBEAN
# 169  ANTARCTICA  2.800000e+04      2019                         ANTARCTICA
# 170        NIUE  8.000000e+03      2019              AUSTRALIA AND OCEANIA
# 171      TUVALU  0.000000e+00      2019              AUSTRALIA AND OCEANIA
#
#     Countryname                                  Officialstatename  \
# 0         CHINA                     The People's Republic of China
# 1         INDIA                              The Republic of India
# 2         JAPAN                                              Japan
# 3       GERMANY                    The Federal Republic of Germany
# 4        CANADA                                             Canada
# ..          ...                                                ...
# 167       NAURU                              The Republic of Nauru
# 168  MONTSERRAT                                         Montserrat
# 169  ANTARCTICA  All land and ice shelves south of the 60th par...
# 170        NIUE                                               Niue
# 171      TUVALU                                             Tuvalu
#
#     InternetccTLD iso2 iso3
# 0             .cn   CN  CHN
# 1             .in   IN  IND
# 2             .jp   JP  JPN
# 3             .de   DE  DEU
# 4             .ca   CA  CAN
# ..            ...  ...  ...
# 167           .nr   NR  NRU
# 168           .ms   MS  MSR
# 169           .aq   AQ  ATA
# 170           .nu   NU  NIU
# 171           .tv   TV  TUV
#
# [172 rows x 9 columns]

# %% [markdown]
# 2. You keep all the keys from one data frame:
#
# The final rows will be all the rows from the dataframe (here from the _left_). If a key values does not find a match, the key value is kept, but the columns will have missing values. In this case, your count of rows will be equal to the amount of rows of the data frame to the left. You can also use **right** so the same logic applies to the data frame to the right.

# %%
# how many resulting rows after left merging
co2.merge(isoCodes,how='left',left_on='name',right_on='Countryname')
# Out:
#                                               name           co2  co2_date  \
# 0                                            CHINA  1.077325e+10      2019
# 1                                    UNITED STATES  5.144361e+09      2019
# 2                                            INDIA  2.314738e+09      2019
# 3                                           RUSSIA  1.848070e+09      2019
# 4                                            JAPAN  1.103234e+09      2019
# ..                                             ...           ...       ...
# 213                                     ANTARCTICA  2.800000e+04      2019
# 214  SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA  1.300000e+04      2019
# 215                                           NIUE  8.000000e+03      2019
# 216                       NORTHERN MARIANA ISLANDS  0.000000e+00      2019
# 217                                         TUVALU  0.000000e+00      2019
#
#                       region Countryname  \
# 0    EAST AND SOUTHEAST ASIA       CHINA
# 1              NORTH AMERICA         NaN
# 2                 SOUTH ASIA       INDIA
# 3               CENTRAL ASIA         NaN
# 4    EAST AND SOUTHEAST ASIA       JAPAN
# ..                       ...         ...
# 213               ANTARCTICA  ANTARCTICA
# 214                   AFRICA         NaN
# 215    AUSTRALIA AND OCEANIA        NIUE
# 216    AUSTRALIA AND OCEANIA         NaN
# 217    AUSTRALIA AND OCEANIA      TUVALU
#
#                                      Officialstatename InternetccTLD iso2 iso3
# 0                       The People's Republic of China           .cn   CN  CHN
# 1                                                  NaN           NaN  NaN  NaN
# 2                                The Republic of India           .in   IN  IND
# 3                                                  NaN           NaN  NaN  NaN
# 4                                                Japan           .jp   JP  JPN
# ..                                                 ...           ...  ...  ...
# 213  All land and ice shelves south of the 60th par...           .aq   AQ  ATA
# 214                                                NaN           NaN  NaN  NaN
# 215                                               Niue           .nu   NU  NIU
# 216                                                NaN           NaN  NaN  NaN
# 217                                             Tuvalu           .tv   TV  TUV
#
# [218 rows x 9 columns]

# %% [markdown]
# 3. You keep all the rows from both data frames:
#
# In this case you will obtain all possible rows: the matched values, and the unmatched values from both data frames. You will also generate missing values. In this case, your count of rows will be at least the amount of rows of the data frame with the most rows.

# %%
# how many resulting rows after outer merging
co2.merge(isoCodes,how='outer',left_on='name',right_on='Countryname')
# Out:
#               name           co2  co2_date                   region  \
# 0            CHINA  1.077325e+10    2019.0  EAST AND SOUTHEAST ASIA
# 1    UNITED STATES  5.144361e+09    2019.0            NORTH AMERICA
# 2            INDIA  2.314738e+09    2019.0               SOUTH ASIA
# 3           RUSSIA  1.848070e+09    2019.0             CENTRAL ASIA
# 4            JAPAN  1.103234e+09    2019.0  EAST AND SOUTHEAST ASIA
# ..             ...           ...       ...                      ...
# 290            NaN           NaN       NaN                      NaN
# 291            NaN           NaN       NaN                      NaN
# 292            NaN           NaN       NaN                      NaN
# 293            NaN           NaN       NaN                      NaN
# 294            NaN           NaN       NaN                      NaN
#
#                   Countryname                               Officialstatename  \
# 0                       CHINA                  The People's Republic of China
# 1                         NaN                                             NaN
# 2                       INDIA                           The Republic of India
# 3                         NaN                                             NaN
# 4                       JAPAN                                           Japan
# ..                        ...                                             ...
# 290                  VIET NAM              The Socialist Republic of Viet Nam
# 291  VIRGIN ISLANDS (BRITISH)                              The Virgin Islands
# 292     VIRGIN ISLANDS (U.S.)         The Virgin Islands of the United States
# 293         WALLIS AND FUTUNA  The Territory of the Wallis and Futuna Islands
# 294            WESTERN SAHARA            The Sahrawi Arab Democratic Republic
#
#     InternetccTLD iso2 iso3
# 0             .cn   CN  CHN
# 1             NaN  NaN  NaN
# 2             .in   IN  IND
# 3             NaN  NaN  NaN
# 4             .jp   JP  JPN
# ..            ...  ...  ...
# 290           .vn   VN  VNM
# 291           .vg   VG  VGB
# 292           .vi   VI  VIR
# 293           .wf   WF  WLF
# 294           NaN   EH  ESH
#
# [295 rows x 9 columns]

# %% [markdown]
# Your merge should not produce missing values, so the **inner** approach is in general preferred. But that approach loses several rows.
#
# In this situation, we speak of **fuzzy merging**.

# %% [markdown]
# **Step 1**: Detect what values are present in the right data frame, but not present in the left data frame:

# %%
onlyCo2=set(co2.name)-set(isoCodes.Countryname)
onlyISO=set(isoCodes.Countryname)-set(co2.name)

# %%
onlyCo2
# Out:
# {'BAHAMAS, THE',
#  'BOLIVIA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRUNEI',
#  'BURMA',
#  'CAYMAN ISLANDS',
#  'CENTRAL AFRICAN REPUBLIC',
#  'COMOROS',
#  'CONGO, DEMOCRATIC REPUBLIC OF THE',
#  'CONGO, REPUBLIC OF THE',
#  'COOK ISLANDS',
#  "COTE D'IVOIRE",
#  'DOMINICAN REPUBLIC',
#  'FALKLAND ISLANDS (ISLAS MALVINAS)',
#  'FAROE ISLANDS',
#  'GAMBIA, THE',
#  'GAZA STRIP',
#  'IRAN',
#  'KOREA, NORTH',
#  'KOREA, SOUTH',
#  'KOSOVO',
#  'LAOS',
#  'MACAU',
#  'MARSHALL ISLANDS',
#  'MICRONESIA, FEDERATED STATES OF',
#  'MOLDOVA',
#  'NETHERLANDS',
#  'NIGER',
#  'NORTHERN MARIANA ISLANDS',
#  'PHILIPPINES',
#  'RUSSIA',
#  'SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA',
#  'SUDAN',
#  'SYRIA',
#  'TAIWAN',
#  'TANZANIA',
#  'TURKEY (TURKIYE)',
#  'TURKS AND CAICOS ISLANDS',
#  'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM',
#  'UNITED STATES',
#  'VENEZUELA',
#  'VIETNAM',
#  'VIRGIN ISLANDS',
#  'WAKE ISLAND',
#  'WEST BANK'}

# %%
onlyISO
# Out:
# {'ANDORRA',
#  'ANGUILLA',
#  'BAHAMAS (THE)',
#  'BOLIVIA (PLURINATIONAL STATE OF)',
#  'BONAIRE\xa0SINT EUSTATIUS\xa0SABA',
#  'BOUVET ISLAND',
#  'BRITISH INDIAN OCEAN TERRITORY (THE)',
#  'BRUNEI DARUSSALAM',
#  'CAYMAN ISLANDS (THE)',
#  'CENTRAL AFRICAN REPUBLIC (THE)',
#  'CHRISTMAS ISLAND',
#  'COCOS (KEELING) ISLANDS (THE)',
#  'COMOROS (THE)',
#  'CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#  'CONGO (THE)',
#  'COOK ISLANDS (THE)',
#  'CURAÇAO',
#  "CÔTE D'IVOIRE",
#  'DOMINICAN REPUBLIC (THE)',
#  'FALKLAND ISLANDS (THE)',
#  'FAROE ISLANDS (THE)',
#  'FRENCH GUIANA',
#  'FRENCH SOUTHERN TERRITORIES (THE)',
#  'GAMBIA (THE)',
#  'GUADELOUPE',
#  'GUERNSEY',
#  'HEARD ISLAND AND MCDONALD ISLANDS',
#  'HOLY SEE (THE)',
#  'IRAN (ISLAMIC REPUBLIC OF)',
#  'ISLE OF MAN',
#  "KOREA (THE DEMOCRATIC PEOPLE'S REPUBLIC OF)",
#  'KOREA (THE REPUBLIC OF)',
#  "LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
#  'LIECHTENSTEIN',
#  'MACAO',
#  'MARSHALL ISLANDS (THE)',
#  'MARTINIQUE',
#  'MAYOTTE',
#  'MICRONESIA (FEDERATED STATES OF)',
#  'MOLDOVA (THE REPUBLIC OF)',
#  'MONACO',
#  'MYANMAR',
#  'NETHERLANDS (THE)',
#  'NIGER (THE)',
#  'NORFOLK ISLAND',
#  'NORTHERN MARIANA ISLANDS (THE)',
#  'PALAU',
#  'PALESTINE, STATE OF',
#  'PHILIPPINES (THE)',
#  'PITCAIRN',
#  'RUSSIAN FEDERATION (THE)',
#  'RÉUNION',
#  'SAINT BARTHÉLEMY',
#  'SAINT HELENA\xa0ASCENSION ISLAND\xa0TRISTAN DA CUNHA',
#  'SAINT MARTIN (FRENCH PART)',
#  'SAN MARINO',
#  'SINT MAARTEN (DUTCH PART)',
#  'SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS',
#  'SUDAN (THE)',
#  'SVALBARD\xa0JAN MAYEN',
#  'SYRIAN ARAB REPUBLIC (THE)',
#  'TAIWAN (PROVINCE OF CHINA)',
#  'TANZANIA, THE UNITED REPUBLIC OF',
#  'TOKELAU',
#  'TURKEY',
#  'TURKS AND CAICOS ISLANDS (THE)',
#  'UNITED ARAB EMIRATES (THE)',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#  'UNITED STATES MINOR OUTLYING ISLANDS (THE)',
#  'UNITED STATES OF AMERICA (THE)',
#  'VENEZUELA (BOLIVARIAN REPUBLIC OF)',
#  'VIET NAM',
#  'VIRGIN ISLANDS (BRITISH)',
#  'VIRGIN ISLANDS (U.S.)',
#  'WALLIS AND FUTUNA',
#  'WESTERN SAHARA',
#  'ÅLAND ISLANDS'}

# %% [markdown]
# If the same country is written differently, we need to modify one of those columns so that both columns share the same name spelling.

# %%
from thefuzz import process as fz

[(f,fz.extractOne(f, onlyCo2)) for f in sorted(onlyISO)]
# Out:
# [('ANDORRA', ('SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA', 51)),
#  ('ANGUILLA', ('LAOS', 60)),
#  ('BAHAMAS (THE)', ('BAHAMAS, THE', 100)),
#  ('BOLIVIA (PLURINATIONAL STATE OF)', ('BOLIVIA', 90)),
#  ('BONAIRE\xa0SINT EUSTATIUS\xa0SABA', ('UNITED STATES', 56)),
#  ('BOUVET ISLAND', ('FAROE ISLANDS', 69)),
#  ('BRITISH INDIAN OCEAN TERRITORY (THE)', ('BAHAMAS, THE', 86)),
#  ('BRUNEI DARUSSALAM', ('BRUNEI', 90)),
#  ('CAYMAN ISLANDS (THE)', ('CAYMAN ISLANDS', 95)),
#  ('CENTRAL AFRICAN REPUBLIC (THE)', ('CENTRAL AFRICAN REPUBLIC', 95)),
#  ('CHRISTMAS ISLAND', ('WAKE ISLAND', 67)),
#  ('COCOS (KEELING) ISLANDS (THE)', ('VIRGIN ISLANDS', 86)),
#  ('COMOROS (THE)', ('COMOROS', 90)),
#  ('CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#   ('CONGO, DEMOCRATIC REPUBLIC OF THE', 95)),
#  ('CONGO (THE)', ('CONGO, DEMOCRATIC REPUBLIC OF THE', 86)),
#  ('COOK ISLANDS (THE)', ('COOK ISLANDS', 95)),
#  ('CURAÇAO', ('BURMA', 55)),
#  ("CÔTE D'IVOIRE", ("COTE D'IVOIRE", 96)),
#  ('DOMINICAN REPUBLIC (THE)', ('DOMINICAN REPUBLIC', 95)),
#  ('FALKLAND ISLANDS (THE)', ('VIRGIN ISLANDS', 86)),
#  ('FAROE ISLANDS (THE)', ('FAROE ISLANDS', 95)),
#  ('FRENCH GUIANA', ('IRAN', 68)),
#  ('FRENCH SOUTHERN TERRITORIES (THE)', ('BAHAMAS, THE', 86)),
#  ('GAMBIA (THE)', ('GAMBIA, THE', 100)),
#  ('GUADELOUPE', ('LAOS', 45)),
#  ('GUERNSEY', ('NIGER', 46)),
#  ('HEARD ISLAND AND MCDONALD ISLANDS', ('VIRGIN ISLANDS', 86)),
#  ('HOLY SEE (THE)', ('CONGO, DEMOCRATIC REPUBLIC OF THE', 86)),
#  ('IRAN (ISLAMIC REPUBLIC OF)', ('IRAN', 90)),
#  ('ISLE OF MAN', ('CONGO, DEMOCRATIC REPUBLIC OF THE', 86)),
#  ("KOREA (THE DEMOCRATIC PEOPLE'S REPUBLIC OF)", ('BAHAMAS, THE', 86)),
#  ('KOREA (THE REPUBLIC OF)', ('BAHAMAS, THE', 86)),
#  ("LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)", ('BAHAMAS, THE', 86)),
#  ('LIECHTENSTEIN', ('UNITED STATES', 46)),
#  ('MACAO', ('MACAU', 80)),
#  ('MARSHALL ISLANDS (THE)', ('MARSHALL ISLANDS', 95)),
#  ('MARTINIQUE', ('NORTHERN MARIANA ISLANDS', 54)),
#  ('MAYOTTE', ('UNITED ARAB EMIRATES', 51)),
#  ('MICRONESIA (FEDERATED STATES OF)',
#   ('MICRONESIA, FEDERATED STATES OF', 100)),
#  ('MOLDOVA (THE REPUBLIC OF)', ('MOLDOVA', 90)),
#  ('MONACO', ('MACAU', 55)),
#  ('MYANMAR', ('NORTHERN MARIANA ISLANDS', 51)),
#  ('NETHERLANDS (THE)', ('NETHERLANDS', 95)),
#  ('NIGER (THE)', ('NIGER', 90)),
#  ('NORFOLK ISLAND', ('COOK ISLANDS', 77)),
#  ('NORTHERN MARIANA ISLANDS (THE)', ('NORTHERN MARIANA ISLANDS', 95)),
#  ('PALAU', ('MACAU', 60)),
#  ('PALESTINE, STATE OF', ('CONGO, DEMOCRATIC REPUBLIC OF THE', 86)),
#  ('PHILIPPINES (THE)', ('PHILIPPINES', 95)),
#  ('PITCAIRN', ('IRAN', 68)),
#  ('RUSSIAN FEDERATION (THE)', ('RUSSIA', 90)),
#  ('RÉUNION', ('BRUNEI', 67)),
#  ('SAINT BARTHÉLEMY', ('SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA', 86)),
#  ('SAINT HELENA\xa0ASCENSION ISLAND\xa0TRISTAN DA CUNHA',
#   ('SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA', 95)),
#  ('SAINT MARTIN (FRENCH PART)',
#   ('SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA', 86)),
#  ('SAN MARINO', ('NORTHERN MARIANA ISLANDS', 63)),
#  ('SINT MAARTEN (DUTCH PART)', ('MACAU', 54)),
#  ('SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS', ('VIRGIN ISLANDS', 86)),
#  ('SUDAN (THE)', ('SUDAN', 90)),
#  ('SVALBARD\xa0JAN MAYEN', ('SUDAN', 54)),
#  ('SYRIAN ARAB REPUBLIC (THE)', ('SYRIA', 90)),
#  ('TAIWAN (PROVINCE OF CHINA)', ('TAIWAN', 90)),
#  ('TANZANIA, THE UNITED REPUBLIC OF', ('TANZANIA', 90)),
#  ('TOKELAU', ('LAOS', 51)),
#  ('TURKEY', ('TURKEY (TURKIYE)', 90)),
#  ('TURKS AND CAICOS ISLANDS (THE)', ('TURKS AND CAICOS ISLANDS', 95)),
#  ('UNITED ARAB EMIRATES (THE)', ('UNITED ARAB EMIRATES', 95)),
#  ('UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#   ('UNITED KINGDOM', 90)),
#  ('UNITED STATES MINOR OUTLYING ISLANDS (THE)', ('UNITED STATES', 90)),
#  ('UNITED STATES OF AMERICA (THE)', ('UNITED STATES', 90)),
#  ('VENEZUELA (BOLIVARIAN REPUBLIC OF)', ('VENEZUELA', 90)),
#  ('VIET NAM', ('VIETNAM', 93)),
#  ('VIRGIN ISLANDS (BRITISH)', ('BRITISH VIRGIN ISLANDS', 95)),
#  ('VIRGIN ISLANDS (U.S.)', ('VIRGIN ISLANDS', 95)),
#  ('WALLIS AND FUTUNA', ('SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA', 86)),
#  ('WESTERN SAHARA', ('WEST BANK', 57)),
#  ('ÅLAND ISLANDS', ('FALKLAND ISLANDS (ISLAS MALVINAS)', 90))]

# %% [markdown]
# Prepare changes:

# %%
#[(f,fz.extractOne(f, onlyCo2)) for f in sorted(onlyISO)]
# first change
changesIso_1={f:fz.extractOne(f, onlyCo2)[0] 
                 for f in sorted(onlyISO)
                 if fz.extractOne(f, onlyCo2)[1] >=90}
#dict of matches
changesIso_1
# Out:
# {'BAHAMAS (THE)': 'BAHAMAS, THE',
#  'BOLIVIA (PLURINATIONAL STATE OF)': 'BOLIVIA',
#  'BRUNEI DARUSSALAM': 'BRUNEI',
#  'CAYMAN ISLANDS (THE)': 'CAYMAN ISLANDS',
#  'CENTRAL AFRICAN REPUBLIC (THE)': 'CENTRAL AFRICAN REPUBLIC',
#  'COMOROS (THE)': 'COMOROS',
#  'CONGO (THE DEMOCRATIC REPUBLIC OF THE)': 'CONGO, DEMOCRATIC REPUBLIC OF THE',
#  'COOK ISLANDS (THE)': 'COOK ISLANDS',
#  "CÔTE D'IVOIRE": "COTE D'IVOIRE",
#  'DOMINICAN REPUBLIC (THE)': 'DOMINICAN REPUBLIC',
#  'FAROE ISLANDS (THE)': 'FAROE ISLANDS',
#  'GAMBIA (THE)': 'GAMBIA, THE',
#  'IRAN (ISLAMIC REPUBLIC OF)': 'IRAN',
#  'MARSHALL ISLANDS (THE)': 'MARSHALL ISLANDS',
#  'MICRONESIA (FEDERATED STATES OF)': 'MICRONESIA, FEDERATED STATES OF',
#  'MOLDOVA (THE REPUBLIC OF)': 'MOLDOVA',
#  'NETHERLANDS (THE)': 'NETHERLANDS',
#  'NIGER (THE)': 'NIGER',
#  'NORTHERN MARIANA ISLANDS (THE)': 'NORTHERN MARIANA ISLANDS',
#  'PHILIPPINES (THE)': 'PHILIPPINES',
#  'RUSSIAN FEDERATION (THE)': 'RUSSIA',
#  'SAINT HELENA\xa0ASCENSION ISLAND\xa0TRISTAN DA CUNHA': 'SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA',
#  'SUDAN (THE)': 'SUDAN',
#  'SYRIAN ARAB REPUBLIC (THE)': 'SYRIA',
#  'TAIWAN (PROVINCE OF CHINA)': 'TAIWAN',
#  'TANZANIA, THE UNITED REPUBLIC OF': 'TANZANIA',
#  'TURKEY': 'TURKEY (TURKIYE)',
#  'TURKS AND CAICOS ISLANDS (THE)': 'TURKS AND CAICOS ISLANDS',
#  'UNITED ARAB EMIRATES (THE)': 'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)': 'UNITED KINGDOM',
#  'UNITED STATES MINOR OUTLYING ISLANDS (THE)': 'UNITED STATES',
#  'UNITED STATES OF AMERICA (THE)': 'UNITED STATES',
#  'VENEZUELA (BOLIVARIAN REPUBLIC OF)': 'VENEZUELA',
#  'VIET NAM': 'VIETNAM',
#  'VIRGIN ISLANDS (BRITISH)': 'BRITISH VIRGIN ISLANDS',
#  'VIRGIN ISLANDS (U.S.)': 'VIRGIN ISLANDS',
#  'ÅLAND ISLANDS': 'FALKLAND ISLANDS (ISLAS MALVINAS)'}

# %%
# make changes
isoCodes.Countryname.replace(to_replace=changesIso_1,inplace=True)

# %% [markdown]
# Second iteration

# %%
onlyCo2=set(co2.name)-set(isoCodes.Countryname)
onlyISO=set(isoCodes.Countryname)-set(co2.name)

[(f,fz.extractOne(f, onlyCo2)) for f in sorted(onlyISO)]
# Out:
# [('ANDORRA', ('KOREA, NORTH', 51)),
#  ('ANGUILLA', ('LAOS', 60)),
#  ('BONAIRE\xa0SINT EUSTATIUS\xa0SABA', ('WEST BANK', 48)),
#  ('BOUVET ISLAND', ('WAKE ISLAND', 67)),
#  ('BRITISH INDIAN OCEAN TERRITORY (THE)', ('CONGO, REPUBLIC OF THE', 86)),
#  ('CHRISTMAS ISLAND', ('WAKE ISLAND', 67)),
#  ('COCOS (KEELING) ISLANDS (THE)', ('WAKE ISLAND', 70)),
#  ('CONGO (THE)', ('CONGO, REPUBLIC OF THE', 86)),
#  ('CURAÇAO', ('BURMA', 55)),
#  ('FALKLAND ISLANDS (THE)', ('WAKE ISLAND', 66)),
#  ('FRENCH GUIANA', ('WAKE ISLAND', 42)),
#  ('FRENCH SOUTHERN TERRITORIES (THE)', ('KOREA, SOUTH', 62)),
#  ('GUADELOUPE', ('LAOS', 45)),
#  ('GUERNSEY', ('BURMA', 36)),
#  ('HEARD ISLAND AND MCDONALD ISLANDS', ('WAKE ISLAND', 86)),
#  ('HOLY SEE (THE)', ('CONGO, REPUBLIC OF THE', 86)),
#  ('ISLE OF MAN', ('CONGO, REPUBLIC OF THE', 86)),
#  ("KOREA (THE DEMOCRATIC PEOPLE'S REPUBLIC OF)",
#   ('CONGO, REPUBLIC OF THE', 86)),
#  ('KOREA (THE REPUBLIC OF)', ('KOREA, NORTH', 86)),
#  ("LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)", ('CONGO, REPUBLIC OF THE', 86)),
#  ('LIECHTENSTEIN', ('WEST BANK', 36)),
#  ('MACAO', ('MACAU', 80)),
#  ('MARTINIQUE', ('MACAU', 40)),
#  ('MAYOTTE', ('LAOS', 45)),
#  ('MONACO', ('MACAU', 55)),
#  ('MYANMAR', ('MACAU', 50)),
#  ('NORFOLK ISLAND', ('WAKE ISLAND', 67)),
#  ('PALAU', ('MACAU', 60)),
#  ('PALESTINE, STATE OF', ('LAOS', 45)),
#  ('PITCAIRN', ('MACAU', 36)),
#  ('RÉUNION', ('KOREA, NORTH', 43)),
#  ('SAINT BARTHÉLEMY', ('WEST BANK', 42)),
#  ('SAINT MARTIN (FRENCH PART)', ('WEST BANK', 40)),
#  ('SAN MARINO', ('LAOS', 43)),
#  ('SINT MAARTEN (DUTCH PART)', ('MACAU', 54)),
#  ('SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS',
#   ('CONGO, REPUBLIC OF THE', 86)),
#  ('SVALBARD\xa0JAN MAYEN', ('LAOS', 45)),
#  ('TOKELAU', ('LAOS', 51)),
#  ('WALLIS AND FUTUNA', ('WAKE ISLAND', 58)),
#  ('WESTERN SAHARA', ('WEST BANK', 57))]

# %% [markdown]
# This second iteration gives weird results. Let's use a different function to get more than one result:

# %%
[(f,fz.extract(f, onlyCo2)) for f in sorted(onlyISO)]
# Out:
# [('ANDORRA',
#   [('KOREA, NORTH', 51),
#    ('WAKE ISLAND', 49),
#    ('CONGO, REPUBLIC OF THE', 39),
#    ('LAOS', 36),
#    ('BURMA', 33)]),
#  ('ANGUILLA',
#   [('LAOS', 60),
#    ('WAKE ISLAND', 42),
#    ('BURMA', 36),
#    ('MACAU', 36),
#    ('CONGO, REPUBLIC OF THE', 27)]),
#  ('BONAIRE\xa0SINT EUSTATIUS\xa0SABA',
#   [('WEST BANK', 48),
#    ('KOREA, NORTH', 45),
#    ('KOREA, SOUTH', 45),
#    ('GAZA STRIP', 43),
#    ('WAKE ISLAND', 40)]),
#  ('BOUVET ISLAND',
#   [('WAKE ISLAND', 67),
#    ('LAOS', 45),
#    ('WEST BANK', 45),
#    ('BURMA', 36),
#    ('KOREA, NORTH', 32)]),
#  ('BRITISH INDIAN OCEAN TERRITORY (THE)',
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('WEST BANK', 48),
#    ('GAZA STRIP', 45),
#    ('KOREA, NORTH', 45),
#    ('KOREA, SOUTH', 45)]),
#  ('CHRISTMAS ISLAND',
#   [('WAKE ISLAND', 67),
#    ('LAOS', 45),
#    ('WEST BANK', 40),
#    ('BURMA', 36),
#    ('MACAU', 36)]),
#  ('COCOS (KEELING) ISLANDS (THE)',
#   [('WAKE ISLAND', 70),
#    ('CONGO, REPUBLIC OF THE', 52),
#    ('LAOS', 45),
#    ('WEST BANK', 38),
#    ('KOREA, NORTH', 38)]),
#  ('CONGO (THE)',
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('KOREA, NORTH', 48),
#    ('KOREA, SOUTH', 45),
#    ('WEST BANK', 31),
#    ('GAZA STRIP', 30)]),
#  ('CURAÇAO',
#   [('BURMA', 55),
#    ('LAOS', 51),
#    ('KOREA, NORTH', 43),
#    ('KOREA, SOUTH', 43),
#    ('MACAU', 36)]),
#  ('FALKLAND ISLANDS (THE)',
#   [('WAKE ISLAND', 66),
#    ('LAOS', 45),
#    ('WEST BANK', 38),
#    ('KOREA, NORTH', 38),
#    ('KOREA, SOUTH', 38)]),
#  ('FRENCH GUIANA',
#   [('WAKE ISLAND', 42),
#    ('BURMA', 36),
#    ('MACAU', 36),
#    ('WEST BANK', 36),
#    ('CONGO, REPUBLIC OF THE', 32)]),
#  ('FRENCH SOUTHERN TERRITORIES (THE)',
#   [('KOREA, SOUTH', 62),
#    ('KOREA, NORTH', 52),
#    ('CONGO, REPUBLIC OF THE', 41),
#    ('WEST BANK', 38),
#    ('GAZA STRIP', 36)]),
#  ('GUADELOUPE',
#   [('LAOS', 45),
#    ('BURMA', 36),
#    ('CONGO, REPUBLIC OF THE', 31),
#    ('GAZA STRIP', 30),
#    ('WAKE ISLAND', 29)]),
#  ('GUERNSEY',
#   [('BURMA', 36),
#    ('CONGO, REPUBLIC OF THE', 34),
#    ('WEST BANK', 24),
#    ('GAZA STRIP', 22),
#    ('LAOS', 22)]),
#  ('HEARD ISLAND AND MCDONALD ISLANDS',
#   [('WAKE ISLAND', 86),
#    ('WEST BANK', 38),
#    ('MACAU', 36),
#    ('KOREA, NORTH', 31),
#    ('KOREA, SOUTH', 31)]),
#  ('HOLY SEE (THE)',
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('KOREA, NORTH', 48),
#    ('KOREA, SOUTH', 48),
#    ('LAOS', 45),
#    ('KOSOVO', 30)]),
#  ('ISLE OF MAN',
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('WAKE ISLAND', 52),
#    ('LAOS', 45),
#    ('WEST BANK', 40),
#    ('BURMA', 36)]),
#  ("KOREA (THE DEMOCRATIC PEOPLE'S REPUBLIC OF)",
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('KOREA, NORTH', 86),
#    ('KOREA, SOUTH', 86),
#    ('WEST BANK', 38),
#    ('MACAU', 36)]),
#  ('KOREA (THE REPUBLIC OF)',
#   [('KOREA, NORTH', 86),
#    ('KOREA, SOUTH', 86),
#    ('CONGO, REPUBLIC OF THE', 79),
#    ('GAZA STRIP', 45),
#    ('LAOS', 43)]),
#  ("LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('MACAU', 54),
#    ('LAOS', 45),
#    ('KOREA, NORTH', 45),
#    ('KOREA, SOUTH', 45)]),
#  ('LIECHTENSTEIN',
#   [('WEST BANK', 36),
#    ('CONGO, REPUBLIC OF THE', 34),
#    ('GAZA STRIP', 26),
#    ('WAKE ISLAND', 25),
#    ('LAOS', 24)]),
#  ('MACAO',
#   [('MACAU', 80),
#    ('LAOS', 44),
#    ('BURMA', 40),
#    ('CONGO, REPUBLIC OF THE', 36),
#    ('GAZA STRIP', 36)]),
#  ('MARTINIQUE',
#   [('MACAU', 40),
#    ('BURMA', 36),
#    ('GAZA STRIP', 30),
#    ('WEST BANK', 30),
#    ('WAKE ISLAND', 29)]),
#  ('MAYOTTE',
#   [('LAOS', 45),
#    ('CONGO, REPUBLIC OF THE', 39),
#    ('KOREA, NORTH', 37),
#    ('KOREA, SOUTH', 37),
#    ('BURMA', 33)]),
#  ('MONACO',
#   [('MACAU', 55),
#    ('LAOS', 51),
#    ('CONGO, REPUBLIC OF THE', 45),
#    ('BURMA', 36),
#    ('KOREA, NORTH', 33)]),
#  ('MYANMAR',
#   [('MACAU', 50),
#    ('KOREA, NORTH', 39),
#    ('WAKE ISLAND', 37),
#    ('GAZA STRIP', 35),
#    ('BURMA', 33)]),
#  ('NORFOLK ISLAND',
#   [('WAKE ISLAND', 67),
#    ('LAOS', 45),
#    ('KOREA, NORTH', 38),
#    ('CONGO, REPUBLIC OF THE', 32),
#    ('KOREA, SOUTH', 31)]),
#  ('PALAU',
#   [('MACAU', 60),
#    ('LAOS', 44),
#    ('WAKE ISLAND', 38),
#    ('CONGO, REPUBLIC OF THE', 36),
#    ('GAZA STRIP', 36)]),
#  ('PALESTINE, STATE OF',
#   [('LAOS', 45),
#    ('CONGO, REPUBLIC OF THE', 44),
#    ('WEST BANK', 40),
#    ('WAKE ISLAND', 38),
#    ('KOREA, SOUTH', 38)]),
#  ('PITCAIRN',
#   [('MACAU', 36),
#    ('WEST BANK', 35),
#    ('CONGO, REPUBLIC OF THE', 34),
#    ('WAKE ISLAND', 32),
#    ('GAZA STRIP', 22)]),
#  ('RÉUNION',
#   [('KOREA, NORTH', 43),
#    ('GAZA STRIP', 32),
#    ('CONGO, REPUBLIC OF THE', 30),
#    ('WAKE ISLAND', 30),
#    ('KOREA, SOUTH', 28)]),
#  ('SAINT BARTHÉLEMY',
#   [('WEST BANK', 42),
#    ('KOREA, NORTH', 37),
#    ('BURMA', 36),
#    ('KOREA, SOUTH', 36),
#    ('MACAU', 34)]),
#  ('SAINT MARTIN (FRENCH PART)',
#   [('WEST BANK', 40),
#    ('KOREA, NORTH', 39),
#    ('BURMA', 36),
#    ('MACAU', 36),
#    ('CONGO, REPUBLIC OF THE', 34)]),
#  ('SAN MARINO',
#   [('LAOS', 43),
#    ('WEST BANK', 42),
#    ('GAZA STRIP', 40),
#    ('WAKE ISLAND', 38),
#    ('BURMA', 36)]),
#  ('SINT MAARTEN (DUTCH PART)',
#   [('MACAU', 54),
#    ('KOREA, SOUTH', 52),
#    ('KOREA, NORTH', 45),
#    ('WEST BANK', 38),
#    ('BURMA', 36)]),
#  ('SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS',
#   [('CONGO, REPUBLIC OF THE', 86),
#    ('KOREA, SOUTH', 86),
#    ('WAKE ISLAND', 66),
#    ('KOREA, NORTH', 52),
#    ('WEST BANK', 50)]),
#  ('SVALBARD\xa0JAN MAYEN',
#   [('LAOS', 45),
#    ('WEST BANK', 38),
#    ('BURMA', 36),
#    ('MACAU', 36),
#    ('WAKE ISLAND', 34)]),
#  ('TOKELAU',
#   [('LAOS', 51),
#    ('WAKE ISLAND', 44),
#    ('KOREA, SOUTH', 42),
#    ('KOREA, NORTH', 39),
#    ('MACAU', 33)]),
#  ('WALLIS AND FUTUNA',
#   [('WAKE ISLAND', 58),
#    ('WEST BANK', 50),
#    ('LAOS', 45),
#    ('BURMA', 36),
#    ('MACAU', 34)]),
#  ('WESTERN SAHARA',
#   [('WEST BANK', 57),
#    ('GAZA STRIP', 48),
#    ('WAKE ISLAND', 40),
#    ('KOREA, SOUTH', 38),
#    ('BURMA', 36)])]

# %%
# remember you can use this for a particular case:
isoCodes.loc[isoCodes.Countryname.str.contains('LAO')]
# Out:
#                                 Countryname  \
# 122  LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)
#
#                         Officialstatename InternetccTLD iso2 iso3
# 122  The Lao People's Democratic Republic           .la   LA  LAO

# %% [markdown]
# Then, just prepare manual changes:

# %%
changesIso_2={'CONGO (THE)':'CONGO, REPUBLIC OF THE',
              "KOREA (THE DEMOCRATIC PEOPLE'S REPUBLIC OF)":'KOREA, NORTH',
             'KOREA (THE REPUBLIC OF)':'KOREA, SOUTH',
             "LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)":'LAOS',
             'MACAO':'MACAU',
             'MYANMAR':"BURMA"}
isoCodes.Countryname.replace(to_replace=changesIso_2,inplace=True)

# %% [markdown]
# Then,

# %%
onlyCo2=set(co2.name)-set(isoCodes.Countryname)
onlyISO=set(isoCodes.Countryname)-set(co2.name)

[(f,fz.extractOne(f, onlyCo2)) for f in sorted(onlyISO)]
# Out:
# [('ANDORRA', ('WAKE ISLAND', 49)),
#  ('ANGUILLA', ('WAKE ISLAND', 42)),
#  ('BONAIRE\xa0SINT EUSTATIUS\xa0SABA', ('WEST BANK', 48)),
#  ('BOUVET ISLAND', ('WAKE ISLAND', 67)),
#  ('BRITISH INDIAN OCEAN TERRITORY (THE)', ('WEST BANK', 48)),
#  ('CHRISTMAS ISLAND', ('WAKE ISLAND', 67)),
#  ('COCOS (KEELING) ISLANDS (THE)', ('WAKE ISLAND', 70)),
#  ('CURAÇAO', ('GAZA STRIP', 30)),
#  ('FALKLAND ISLANDS (THE)', ('WAKE ISLAND', 66)),
#  ('FRENCH GUIANA', ('WAKE ISLAND', 42)),
#  ('FRENCH SOUTHERN TERRITORIES (THE)', ('WEST BANK', 38)),
#  ('GUADELOUPE', ('GAZA STRIP', 30)),
#  ('GUERNSEY', ('WEST BANK', 24)),
#  ('HEARD ISLAND AND MCDONALD ISLANDS', ('WAKE ISLAND', 86)),
#  ('HOLY SEE (THE)', ('KOSOVO', 30)),
#  ('ISLE OF MAN', ('WAKE ISLAND', 52)),
#  ('LIECHTENSTEIN', ('WEST BANK', 36)),
#  ('MARTINIQUE', ('GAZA STRIP', 30)),
#  ('MAYOTTE', ('WAKE ISLAND', 26)),
#  ('MONACO', ('KOSOVO', 33)),
#  ('NORFOLK ISLAND', ('WAKE ISLAND', 67)),
#  ('PALAU', ('WAKE ISLAND', 38)),
#  ('PALESTINE, STATE OF', ('WEST BANK', 40)),
#  ('PITCAIRN', ('WEST BANK', 35)),
#  ('RÉUNION', ('GAZA STRIP', 32)),
#  ('SAINT BARTHÉLEMY', ('WEST BANK', 42)),
#  ('SAINT MARTIN (FRENCH PART)', ('WEST BANK', 40)),
#  ('SAN MARINO', ('WEST BANK', 42)),
#  ('SINT MAARTEN (DUTCH PART)', ('WEST BANK', 38)),
#  ('SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS', ('WAKE ISLAND', 66)),
#  ('SVALBARD\xa0JAN MAYEN', ('WEST BANK', 38)),
#  ('TOKELAU', ('WAKE ISLAND', 44)),
#  ('WALLIS AND FUTUNA', ('WAKE ISLAND', 58)),
#  ('WESTERN SAHARA', ('WEST BANK', 57))]

# %% [markdown]
# Notice this:

# %%
isoCodes.loc[isoCodes.Countryname.str.contains('PALES')]
# Out:
#              Countryname       Officialstatename InternetccTLD iso2 iso3
# 170  PALESTINE, STATE OF  The State of Palestine           .ps   PS  PSE

# %%
co2.loc[co2.name.str.contains('GAZ|BANK')]
# Out:
#            name        co2  co2_date       region
# 144  GAZA STRIP  3341000.0      2019  MIDDLE EAST
# 145   WEST BANK  3341000.0      2019  MIDDLE EAST

# %% [markdown]
# We could do this:

# %%
changesCo2={'GAZA STRIP':'PALESTINE, STATE OF'}
co2.name.replace(to_replace=changesCo2,inplace=True)

# %% [markdown]
# Now, let's merge:

# %%
ciaiso=co2.merge(isoCodes,how='inner',left_on='name',right_on='Countryname')
ciaiso
# Out:
#                                               name           co2  co2_date  \
# 0                                            CHINA  1.077325e+10      2019
# 1                                    UNITED STATES  5.144361e+09      2019
# 2                                    UNITED STATES  5.144361e+09      2019
# 3                                            INDIA  2.314738e+09      2019
# 4                                           RUSSIA  1.848070e+09      2019
# ..                                             ...           ...       ...
# 211                                     ANTARCTICA  2.800000e+04      2019
# 212  SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA  1.300000e+04      2019
# 213                                           NIUE  8.000000e+03      2019
# 214                       NORTHERN MARIANA ISLANDS  0.000000e+00      2019
# 215                                         TUVALU  0.000000e+00      2019
#
#                       region                                    Countryname  \
# 0    EAST AND SOUTHEAST ASIA                                          CHINA
# 1              NORTH AMERICA                                  UNITED STATES
# 2              NORTH AMERICA                                  UNITED STATES
# 3                 SOUTH ASIA                                          INDIA
# 4               CENTRAL ASIA                                         RUSSIA
# ..                       ...                                            ...
# 211               ANTARCTICA                                     ANTARCTICA
# 212                   AFRICA  SAINT HELENA, ASCENSION, AND TRISTAN DA CUNHA
# 213    AUSTRALIA AND OCEANIA                                           NIUE
# 214    AUSTRALIA AND OCEANIA                       NORTHERN MARIANA ISLANDS
# 215    AUSTRALIA AND OCEANIA                                         TUVALU
#
#                                      Officialstatename InternetccTLD iso2 iso3
# 0                       The People's Republic of China           .cn   CN  CHN
# 1    Baker Island, Howland Island, Jarvis Island, J...           NaN   UM  UMI
# 2                         The United States of America           .us   US  USA
# 3                                The Republic of India           .in   IN  IND
# 4                               The Russian Federation           .ru   RU  RUS
# ..                                                 ...           ...  ...  ...
# 211  All land and ice shelves south of the 60th par...           .aq   AQ  ATA
# 212       Saint Helena, Ascension and Tristan da Cunha           .sh   SH  SHN
# 213                                               Niue           .nu   NU  NIU
# 214   The Commonwealth of the Northern Mariana Islands           .mp   MP  MNP
# 215                                             Tuvalu           .tv   TV  TUV
#
# [216 rows x 9 columns]

# %% [markdown]
# It is always good to check for duplicates in the iso:

# %%
ciaiso[ciaiso.duplicated(subset=['iso3'])]
# Out:
# Empty DataFrame
# Columns: [name, co2, co2_date, region, Countryname, Officialstatename, InternetccTLD, iso2, iso3]
# Index: []

# %% [markdown]
# We do have duplicates:

# %%
ciaiso[ciaiso.duplicated(subset=['name'])]
# Out:
#             name           co2  co2_date         region    Countryname  \
# 2  UNITED STATES  5.144361e+09      2019  NORTH AMERICA  UNITED STATES
#
#               Officialstatename InternetccTLD iso2 iso3
# 2  The United States of America           .us   US  USA

# %%
ciaiso[ciaiso.name=='UNITED STATES']
# Out:
#             name           co2  co2_date         region    Countryname  \
# 1  UNITED STATES  5.144361e+09      2019  NORTH AMERICA  UNITED STATES
# 2  UNITED STATES  5.144361e+09      2019  NORTH AMERICA  UNITED STATES
#
#                                    Officialstatename InternetccTLD iso2 iso3
# 1  Baker Island, Howland Island, Jarvis Island, J...           NaN   UM  UMI
# 2                       The United States of America           .us   US  USA

# %% [markdown]
# We could drop some columns:

# %%
ciaiso.drop(columns=['Countryname','name'],inplace=True)
ciaiso
# Out:
#               co2  co2_date                   region  \
# 0    1.077325e+10      2019  EAST AND SOUTHEAST ASIA
# 1    5.144361e+09      2019            NORTH AMERICA
# 2    5.144361e+09      2019            NORTH AMERICA
# 3    2.314738e+09      2019               SOUTH ASIA
# 4    1.848070e+09      2019             CENTRAL ASIA
# ..            ...       ...                      ...
# 211  2.800000e+04      2019               ANTARCTICA
# 212  1.300000e+04      2019                   AFRICA
# 213  8.000000e+03      2019    AUSTRALIA AND OCEANIA
# 214  0.000000e+00      2019    AUSTRALIA AND OCEANIA
# 215  0.000000e+00      2019    AUSTRALIA AND OCEANIA
#
#                                      Officialstatename InternetccTLD iso2 iso3
# 0                       The People's Republic of China           .cn   CN  CHN
# 1    Baker Island, Howland Island, Jarvis Island, J...           NaN   UM  UMI
# 2                         The United States of America           .us   US  USA
# 3                                The Republic of India           .in   IN  IND
# 4                               The Russian Federation           .ru   RU  RUS
# ..                                                 ...           ...  ...  ...
# 211  All land and ice shelves south of the 60th par...           .aq   AQ  ATA
# 212       Saint Helena, Ascension and Tristan da Cunha           .sh   SH  SHN
# 213                                               Niue           .nu   NU  NIU
# 214   The Commonwealth of the Northern Mariana Islands           .mp   MP  MNP
# 215                                             Tuvalu           .tv   TV  TUV
#
# [216 rows x 7 columns]

# %% [markdown]
# This result is very good, but notice you can reorganize the column order like this:

# %%
ciaiso=ciaiso.set_index(['iso3','iso2','InternetccTLD']).reset_index()
ciaiso
# Out:
#     iso3 iso2 InternetccTLD           co2  co2_date                   region  \
# 0    CHN   CN           .cn  1.077325e+10      2019  EAST AND SOUTHEAST ASIA
# 1    UMI   UM           NaN  5.144361e+09      2019            NORTH AMERICA
# 2    USA   US           .us  5.144361e+09      2019            NORTH AMERICA
# 3    IND   IN           .in  2.314738e+09      2019               SOUTH ASIA
# 4    RUS   RU           .ru  1.848070e+09      2019             CENTRAL ASIA
# ..   ...  ...           ...           ...       ...                      ...
# 211  ATA   AQ           .aq  2.800000e+04      2019               ANTARCTICA
# 212  SHN   SH           .sh  1.300000e+04      2019                   AFRICA
# 213  NIU   NU           .nu  8.000000e+03      2019    AUSTRALIA AND OCEANIA
# 214  MNP   MP           .mp  0.000000e+00      2019    AUSTRALIA AND OCEANIA
# 215  TUV   TV           .tv  0.000000e+00      2019    AUSTRALIA AND OCEANIA
#
#                                      Officialstatename
# 0                       The People's Republic of China
# 1    Baker Island, Howland Island, Jarvis Island, J...
# 2                         The United States of America
# 3                                The Republic of India
# 4                               The Russian Federation
# ..                                                 ...
# 211  All land and ice shelves south of the 60th par...
# 212       Saint Helena, Ascension and Tristan da Cunha
# 213                                               Niue
# 214   The Commonwealth of the Northern Mariana Islands
# 215                                             Tuvalu
#
# [216 rows x 7 columns]

# %% [markdown]
# Let's save what we have:

# %%
import os
ciaiso.to_csv(os.path.join("data","ciaiso.csv"), index=False)

# %% [markdown]
# A next step will be to merge _ciaiso_ into an actual map.
# Let's bring the map:

# %%
import geopandas as gpd
import os

#read in:
mapWorld=gpd.read_file(os.path.join("maps","mapWorld.gpkg"),layer="countries_valid")

mapWorld.head()
# Out:
#                 TYPE                       FORMAL_EN    WB_NAME    NAME_EN  \
# 0  Sovereign country           Republic of Indonesia  Indonesia  Indonesia
# 1  Sovereign country                        Malaysia   Malaysia   Malaysia
# 2  Sovereign country               Republic of Chile      Chile      Chile
# 3  Sovereign country  Plurinational State of Bolivia    Bolivia    Bolivia
# 4  Sovereign country                Republic of Peru       Peru       Peru
#
#   FIPS_10_ ISO_A2 ISO_A3 ISO_A3_EH ISO_N3 UN_A3 WB_A2 WB_A3 REGION_UN  \
# 0       ID     ID    IDN       IDN    360   360    ID   IDN      Asia
# 1       MY     MY    MYS       MYS    458   458    MY   MYS      Asia
# 2       CI     CL    CHL       CHL    152   152    CL   CHL  Americas
# 3       BL     BO    BOL       BOL    068   068    BO   BOL  Americas
# 4       PE     PE    PER       PER    604   604    PE   PER  Americas
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.83855 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.90704 4...
# 2  MULTIPOLYGON (((-69.51009 -17.50659, -69.68390...
# 3  POLYGON ((-69.51009 -17.50659, -69.49712 -17.6...
# 4  MULTIPOLYGON (((-69.51009 -17.50659, -69.52260...

# %%
# as usual check dimensions:
mapWorld.shape, ciaiso.shape
# Out:
# ((251, 14), (216, 7))

# %% [markdown]
# Remember that the merge **can not** give you more than the amount of rows *ciaiso* has:

# %%
ciaiso_geo=mapWorld.merge(ciaiso,left_on='ISO_A3', right_on='iso3')

# %%
ciaiso_geo.shape
# Out:
# (221, 21)

# %% [markdown]
# This seems wrong. Let's check:

# %%
ciaiso_geo[ciaiso_geo.duplicated(subset=['ISO_A3'])]
# Out:
#            TYPE       FORMAL_EN              WB_NAME  \
# 212  Dependency   Jarvis Island   Jarvis Island (US)
# 213  Dependency    Baker Island    Baker Island (US)
# 214  Dependency  Howland Island  Howland Island (US)
# 215  Dependency     Wake Island     Wake Island (US)
# 216  Dependency  Midway Islands  Midway Islands (US)
# 217  Dependency  Navassa Island  Navassa Island (US)
# 218  Dependency   Palmyra Atoll   Palmyra Atoll (US)
# 219  Dependency    Kingman Reef    Kingman Reef (US)
#
#                                   NAME_EN FIPS_10_ ISO_A2 ISO_A3 ISO_A3_EH  \
# 212  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 213  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 214  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 215  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 216  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 217  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 218  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 219  United States Minor Outlying Islands      -99     UM    UMI       UMI
#
#     ISO_N3 UN_A3  ... WB_A3                REGION_UN  \
# 212    581  -099  ...   UMI  Seven seas (open ocean)
# 213    581  -099  ...   UMI  Seven seas (open ocean)
# 214    581  -099  ...   UMI  Seven seas (open ocean)
# 215    581  -099  ...   UMI  Seven seas (open ocean)
# 216    581  -099  ...   UMI  Seven seas (open ocean)
# 217    581  -099  ...   USA  Seven seas (open ocean)
# 218    581  -099  ...   UMI  Seven seas (open ocean)
# 219    581  -099  ...   UMI  Seven seas (open ocean)
#
#                                               geometry iso3 iso2  \
# 212  POLYGON ((-160.02998 -0.37615, -160.02477 -0.3...  UMI   UM
# 213  MULTIPOLYGON (((-176.47529 0.19310, -176.47688...  UMI   UM
# 214  POLYGON ((-176.63618 0.79019, -176.63610 0.803...  UMI   UM
# 215  POLYGON ((166.61940 19.28164, 166.64422 19.275...  UMI   UM
# 216  MULTIPOLYGON (((-177.32490 28.20498, -177.3289...  UMI   UM
# 217  POLYGON ((-75.02432 18.41726, -75.01781 18.396...  UMI   UM
# 218  POLYGON ((-162.06086 5.88719, -162.07136 5.890...  UMI   UM
# 219  POLYGON ((-162.40018 6.44514, -162.40018 6.430...  UMI   UM
#
#     InternetccTLD           co2  co2_date         region  \
# 212           NaN  5.144361e+09      2019  NORTH AMERICA
# 213           NaN  5.144361e+09      2019  NORTH AMERICA
# 214           NaN  5.144361e+09      2019  NORTH AMERICA
# 215           NaN  5.144361e+09      2019  NORTH AMERICA
# 216           NaN  5.144361e+09      2019  NORTH AMERICA
# 217           NaN  5.144361e+09      2019  NORTH AMERICA
# 218           NaN  5.144361e+09      2019  NORTH AMERICA
# 219           NaN  5.144361e+09      2019  NORTH AMERICA
#
#                                      Officialstatename
# 212  Baker Island, Howland Island, Jarvis Island, J...
# 213  Baker Island, Howland Island, Jarvis Island, J...
# 214  Baker Island, Howland Island, Jarvis Island, J...
# 215  Baker Island, Howland Island, Jarvis Island, J...
# 216  Baker Island, Howland Island, Jarvis Island, J...
# 217  Baker Island, Howland Island, Jarvis Island, J...
# 218  Baker Island, Howland Island, Jarvis Island, J...
# 219  Baker Island, Howland Island, Jarvis Island, J...
#
# [8 rows x 21 columns]

# %% [markdown]
# These are islands (UMI), but each is a different polygon. So, we are done!

# %% [markdown]
# With ISO codes, this step was easy. Let's save our map with added columns:

# %%
ciaiso_geo.to_file(os.path.join("maps","mapWorld.gpkg"), layer='countries_valid_co2', driver="GPKG")
