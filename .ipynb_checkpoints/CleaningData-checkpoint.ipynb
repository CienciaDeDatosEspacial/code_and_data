# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>

# %% [markdown]
# # Data Cleaning
#
#
# Having data does not always allow you to produce some analytics right away. There is often a lot of pre processing to be done.
#
# This material is about **Cleaning**: making sure each cell has a value that could be used in your coming procedures. There are always some _impurities_ that do not allow the computer to recognize the data correctly, i.e. _commas_ instead of _periods_ and viceversa, the presence of unneeded _blanks_, irrelevant symbols (dollar, euro symbols), or non-standard symbols to represent missing values.
#
# I will use two approaches. The first one is the smart use of regular expressions (**regex**), and the second one a **divide and conquer** strategy.

# %% [markdown]
# # REGEX VERSUS DIVIDE AND CONQUER
#
# Imagine that you request the age people in an online form. Sometimes you run into answers with issues like these:
#
# - "It is:24"
# - "It is: 44"
# - "It is54"
# - "64 it is"
# - "I am twenty"
# - "The 10th I turn 21"
# - "I am 15 years old"
# - "~20"

# %% [markdown]
# From the above examples, you are interested in the _age_, nothing else. The first two cases are _relatively_ easy to solve with divide and conquer, as you see a character that helps:

# %%
case1="It is:24"
case2="It is: 34"
# try 1
case1.split(':')[1]
# Out:
# '24'

# %%
#try 2:
case2.split(':')[1]
# Out:
# ' 34'

# %% [markdown]
# Split broke the string using ":" and produced a _list_.  The number will be the second element. However, in _case2_ you got an extra space. You need to think about a general rule, so maybe this is better:

# %%
case1.split(':')[1].strip()
# Out:
# '24'

# %%
case2.split(':')[1].strip()
# Out:
# '34'

# %% [markdown]
# Using _strip()_ gets rid of the spaces around the string.  Notice _strip()_ and _split()_ are functions in **base Python**. Pandas has its **own** functions.
#
# You can use the divide and conquer as long as every string you find follows the same pattern. Imagine those values make a column in a data frame:

# %%
import pandas as pd

ages=["It is:24","It is: 44","It is54",
      "64 it is","I am twenty","The 10th I turn 21",
      "I am 15 years old","~20"]

someData=pd.DataFrame({'age':ages})
someData
# Out:
#                   age
# 0            It is:24
# 1           It is: 44
# 2             It is54
# 3            64 it is
# 4         I am twenty
# 5  The 10th I turn 21
# 6   I am 15 years old
# 7                 ~20

# %% [markdown]
# Now, let's use Pandas **own** strip and split:

# %%
someData.age.str.split(':')
# Out:
# 0             [It is, 24]
# 1            [It is,  44]
# 2               [It is54]
# 3              [64 it is]
# 4           [I am twenty]
# 5    [The 10th I turn 21]
# 6     [I am 15 years old]
# 7                   [~20]
# Name: age, dtype: object

# %% [markdown]
# Or alternatively:

# %%
someData.age.str.split(':',expand=True)
# Out:
#                     0     1
# 0               It is    24
# 1               It is    44
# 2             It is54  None
# 3            64 it is  None
# 4         I am twenty  None
# 5  The 10th I turn 21  None
# 6   I am 15 years old  None
# 7                 ~20  None

# %% [markdown]
# Notice the use of _expand_. This allows that each element in the list goes to a column. However, as there is **no consistent pattern**, location of the symbol ":", you do not get a good result. The situation requires the **REGEX** approach.
#
# Using regular expressions is a great way to go when there is no pattern to apply the previous strategy; however, it takes time to learn how to build a regular expression that will serve all your especific  needs in a particular situation.
#
# In general, you need to **explore** few *regex pattern*s before deciding what to use. I recommend using **contains()** for that:

# %%
# do each cell has a character that is not a number? (\D)
someData.age.str.contains(pat=r'\D',
                          regex=True)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# Name: age, dtype: bool

# %%
# do each cell has a number character? (\d)
someData.age.str.contains(pat=r'\d',regex=True)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# Name: age, dtype: bool

# %%
# what is that cell?
someData[~someData.age.str.contains(pat=r'\d',regex=True)]
# Out:
#            age
# 4  I am twenty

# %%
# is there a cell where you have 
# symbols beyond [^ ] alphanumeric (\w) or spaces (\s)?  
someData.age[someData.age.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 0     It is:24
# 1    It is: 44
# 7          ~20
# Name: age, dtype: object

# %%
# what happens if I erase all non numbers (\D)?
someData.age.str.replace(pat=r'\D',repl='',regex=True)
# Out:
# 0      24
# 1      44
# 2      54
# 3      64
# 4
# 5    1021
# 6      15
# 7      20
# Name: age, dtype: object

# %%
# what happens if I extract consecutive numeric characters (\d+) ?
someData.age.str.extract(pat=r'(\d+)',expand=True)
# Out:
#      0
# 0   24
# 1   44
# 2   54
# 3   64
# 4  NaN
# 5   10
# 6   15
# 7   20

# %%
# what happens if I erase all 
# numbers (\d+) followed by a texts [[a-z]+] ?
someData.age.str.replace(pat=r'\d+[a-z]+',
                         repl='',
                         regex=True)
# Out:
# 0             It is:24
# 1            It is: 44
# 2              It is54
# 3             64 it is
# 4          I am twenty
# 5       The  I turn 21
# 6    I am 15 years old
# 7                  ~20
# Name: age, dtype: object

# %%
# so:
someData.age.str.replace(pat=r'\d+[a-z]+',
                         repl='',
                         regex=True).\
             str.extract(pat=r'(\d+)',expand=True)
# Out:
#      0
# 0   24
# 1   44
# 2   54
# 3   64
# 4  NaN
# 5   21
# 6   15
# 7   20

# %%
# using or '|'
# ^ beginning of string
# $ end of the string
someData.age.str.extract(pat=r'(^\d+|\d+$|\s\d+\s)',
                         expand=True)
# Out:
#       0
# 0    24
# 1    44
# 2    54
# 3    64
# 4   NaN
# 5    21
# 6   15
# 7    20

# %% [markdown]
# Let me use both results:

# %%
someData['age1']=someData.age.str.replace(pat=r'\d+[a-z]+',
                                          repl='',
                                          regex=True).\
                                str.extract(pat=r'(\d+)',expand=True)

someData['age2']=someData.age.str.extract(pat=r'(^\d+|\d+$|\s\d+\s)',
                         expand=True)

# %%
someData
# Out:
#                   age age1  age2
# 0            It is:24   24    24
# 1           It is: 44   44    44
# 2             It is54   54    54
# 3            64 it is   64    64
# 4         I am twenty  NaN   NaN
# 5  The 10th I turn 21   21    21
# 6   I am 15 years old   15   15
# 7                 ~20   20    20

# %%
someData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      object
#  1   age1    7 non-null      object
#  2   age2    7 non-null      object
# dtypes: object(3)
# memory usage: 320.0+ bytes

# %%
someData['age1'].to_list()==someData['age2'].to_list()
# Out:
# False

# %%
someData['age1']==someData['age2']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
set(someData['age1']) & set(someData['age2'])
# Out:
# {'20', '21', '24', '44', '54', '64', nan}

# %%
set(someData['age1']) ^ set(someData['age2'])
# Out:
# {' 15 ', '15'}

# %%
someData['age1'].to_list()
# Out:
# ['24', '44', '54', '64', nan, '21', '15', '20']

# %%
someData['age2'].to_list()
# Out:
# ['24', '44', '54', '64', nan, '21', ' 15 ', '20']

# %%
someData['age2'].str.strip().to_list()
# Out:
# ['24', '44', '54', '64', nan, '21', '15', '20']

# %% [markdown]
# ## Exercises:

# %% [markdown]
# The CIA has several indicators for world countries:
#
# - See [here](https://www.cia.gov/the-world-factbook/references/guide-to-country-comparisons).
#
# Review the topics related to cleaning discussed in class, and see what may be need to clean this indicator from the CIA:
#
# - [Carbon dioxide emissions](https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison).

# %%
from IPython.display import IFrame  
ciaLink1="https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison" 
IFrame(ciaLink1, width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# You  need to make sure you have installed:
#
# * pandas
# * html5lib
# * lxml
# * beautifulsoup4 (or bs4)
#
# You can use **pip show** to verify (for instance, _pip show pandas_). If you have all of them, run this code to get the data:

# %%
# read web table into pandas DF
import pandas as pd

linkToFile='https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv'
carbon=pd.read_csv(linkToFile)

# %%
# here it is:
carbon
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                           Russia
# 4                                            Japan
# ..                                             ...
# 213                                     Antarctica
# 214  Saint Helena, Ascension, and Tristan da Cunha
# 215                                           Niue
# 216                       Northern Mariana Islands
# 217                                         Tuvalu
#
#                                             slug             value  \
# 0                                          china  10,773,248,000.0
# 1                                  united-states   5,144,361,000.0
# 2                                          india   2,314,738,000.0
# 3                                         russia   1,848,070,000.0
# 4                                          japan   1,103,234,000.0
# ..                                           ...               ...
# 213                                   antarctica          28,000.0
# 214  saint-helena-ascension-and-tristan-da-cunha          13,000.0
# 215                                         niue           8,000.0
# 216                     northern-mariana-islands               0.0
# 217                                       tuvalu               0.0
#
#     date_of_information  ranking                   region
# 0             2019 est.        1  East and Southeast Asia
# 1             2019 est.        2            North America
# 2             2019 est.        3               South Asia
# 3             2019 est.        4             Central Asia
# 4             2019 est.        5  East and Southeast Asia
# ..                  ...      ...                      ...
# 213           2019 est.      214               Antarctica
# 214           2019 est.      215                   Africa
# 215           2019 est.      216    Australia and Oceania
# 216           2019 est.      217    Australia and Oceania
# 217           2019 est.      218    Australia and Oceania
#
# [218 rows x 6 columns]

# %%
# also
carbon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 218 non-null    object
#  1   slug                 218 non-null    object
#  2   value                218 non-null    object
#  3   date_of_information  218 non-null    object
#  4   ranking              218 non-null    int64
#  5   region               218 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 10.3+ KB

# %%
# frequency table
carbon.region.value_counts()
# Out:
# Africa                               55
# Europe                               43
# Central America and the Caribbean    27
# East and Southeast Asia              20
# Australia and Oceania                20
# Middle East                          19
# South America                        13
# South Asia                            8
# North America                         6
# Central Asia                          6
# Antarctica                            1
# Name: region, dtype: int64

# %%
# frequency table
carbon.date_of_information.value_counts()
# Out:
# 2019 est.    216
# 2012 est.      1
# 2017 est.      1
# Name: date_of_information, dtype: int64

# %% [markdown]
# Complete the tasks requested:
#
# 1. Keep the columns _name_, _value_, *date_of_information* and _region_.
#     * Tip: use [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html), [loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html), and [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) for the same purpose (three ways to accomplish the task).
# 2. Change the column name *date_of_information* to *carbon_date*.
#     * Tip: Use [rename](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html).
# 3. Make sure the cells with text does not have neither trailing nor leading spaces.
#     * Tip: use [strip](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html).
# 4. Detect the presence of symbols in the numeric data that are not numeric or point.
#     * Tip: Use [contains](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html).
# 5. Make sure there are no spaces as part of the column names.
#     * Tip: use [replace](https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html).
# 6. Get rid of any value detected in the previous step:
#     * Tip: use [replace](https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html).
# 7. Keep only the year value in the column *carbon_date*.
#     * Tip: use [extract](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.extract.html).
#
# When all tasks are done, create a folder **data** inside the current folder, and save the cleaned file like this:

# %%
# import os

# carbonCleaned.to_csv(os.path.join("data","carbonCleaned.csv"),index=False)

# %% [markdown]
# - Exercise 2: Scrape the data on [Revenue from forest resources](https://www.cia.gov/the-world-factbook/field/revenue-from-forest-resources/country-comparison).

# %%
from IPython.display import IFrame  
ciaLink2="https://www.cia.gov/the-world-factbook/field/revenue-from-forest-resources/country-comparison" 
IFrame(ciaLink2, width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="https://www.cia.gov/the-world-factbook/field/revenue-from-forest-resources/country-comparison"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Let's scrape that data:

# %%
# read web table into pandas DF
import pandas as pd

forestDFs=pd.read_html(ciaLink2, # link
                        header=0, # where is the header?
                        flavor='bs4')

# %%
# check object type 
type(forestDFs)
# Out:
# list

# %%
# check size
len(forestDFs)
# Out:
# 1

# %% [markdown]
# Let's create a copy of that DF:

# %%
# make a copy
forest=forestDFs[0].copy()

# %%
# here it is
forest
# Out:
#      Rank                   Country  % of GDP Date of Information
# 0       1           Solomon Islands     20.27           2018 est.
# 1       2                   Liberia     13.27           2018 est.
# 2       3                   Burundi     10.31           2018 est.
# 3       4             Guinea-Bissau      9.24           2018 est.
# 4       5  Central African Republic      8.99           2018 est.
# ..    ...                       ...       ...                 ...
# 199   200                    Tuvalu      0.00           2018 est.
# 200   201      United Arab Emirates      0.00           2018 est.
# 201   202                Uzbekistan      0.00           2018 est.
# 202   203            Virgin Islands      0.00           2017 est.
# 203   204                 West Bank      0.00           2018 est.
#
# [204 rows x 4 columns]

# %%
# see column names:

forest.columns
# Out:
# Index(['Rank', 'Country', '% of GDP', 'Date of Information'], dtype='object')

# %%
# or

forest.columns.to_list()
# Out:
# ['Rank', 'Country', '% of GDP', 'Date of Information']

# %%
forest['Date of Information'].value_counts()
# Out:
# 2018 est.    195
# 2017 est.      7
# 2015 est.      1
# 2016 est.      1
# Name: Date of Information, dtype: int64

# %% [markdown]
# Complete the tasks requested:
#
# 1. Replace '%' by 'pct'.
#     * Tip: use [replace](https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html).
# 2. Keep the columns _Country_, _pct of GDP_, and *Date of Information*.
#     * Tip: use [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html), [loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html), and [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) for the same purpose (three ways to accomplish the task).
# 3. Change the column name *Date of Information* to *forest_date*.
#     * Tip: Use [rename](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html).
# 4. Make sure there are no spaces as part of the column names.
#     * Tip: use [replace](https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html).
# 5. Make sure the cells with text does not have neither trailing nor leading spaces.
#     * Tip: use [strip](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html).
# 6. Keep only the year value in the column *forest_date*.
#     * Tip: use [extract](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.extract.html).
#
# When all tasks are done, save the cleaned file inside your **data** folder:

# %%
# import os

# forestCleaned.to_csv(os.path.join("data","forestCleaned.csv"),index=False)

# %% [markdown]
# ## The Geo Dataframe
#
# Let's see a  case of **maps represented by polygons**. Let me visit this page from the [World Bank](https://datacatalog.worldbank.org/search/dataset/0038272/World-Bank-Official-Boundaries). I have download the World Boundaries Low Resolution in GeoJSON format.

# %%
import os, geopandas as gpd

worldmap=gpd.read_file(os.path.join("maps","WB_countries_Admin0_lowres.geojson"))

# see
worldmap.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         251 non-null    int64
#  1   OBJECTID    251 non-null    int64
#  2   featurecla  251 non-null    object
#  3   LEVEL       251 non-null    int64
#  4   TYPE        251 non-null    object
#  5   FORMAL_EN   251 non-null    object
#  6   FORMAL_FR   251 non-null    object
#  7   POP_EST     251 non-null    int64
#  8   POP_RANK    251 non-null    int64
#  9   GDP_MD_EST  251 non-null    float64
#  10  POP_YEAR    251 non-null    int64
#  11  LASTCENSUS  251 non-null    int64
#  12  GDP_YEAR    251 non-null    int64
#  13  ECONOMY     251 non-null    object
#  14  INCOME_GRP  251 non-null    object
#  15  FIPS_10_    251 non-null    object
#  16  ISO_A2      251 non-null    object
#  17  ISO_A3      251 non-null    object
#  18  ISO_A3_EH   251 non-null    object
#  19  ISO_N3      251 non-null    object
#  20  UN_A3       251 non-null    object
#  21  WB_A2       251 non-null    object
#  22  WB_A3       251 non-null    object
#  23  CONTINENT   251 non-null    object
#  24  REGION_UN   251 non-null    object
#  25  SUBREGION   251 non-null    object
#  26  REGION_WB   251 non-null    object
#  27  NAME_AR     251 non-null    object
#  28  NAME_BN     251 non-null    object
#  29  NAME_DE     251 non-null    object
#  30  NAME_EN     251 non-null    object
#  31  NAME_ES     251 non-null    object
#  32  NAME_FR     251 non-null    object
#  33  NAME_EL     251 non-null    object
#  34  NAME_HI     251 non-null    object
#  35  NAME_HU     251 non-null    object
#  36  NAME_ID     251 non-null    object
#  37  NAME_IT     251 non-null    object
#  38  NAME_JA     251 non-null    object
#  39  NAME_KO     251 non-null    object
#  40  NAME_NL     251 non-null    object
#  41  NAME_PL     251 non-null    object
#  42  NAME_PT     251 non-null    object
#  43  NAME_RU     251 non-null    object
#  44  NAME_SV     251 non-null    object
#  45  NAME_TR     251 non-null    object
#  46  NAME_VI     251 non-null    object
#  47  NAME_ZH     251 non-null    object
#  48  WB_NAME     251 non-null    object
#  49  WB_RULES    251 non-null    object
#  50  WB_REGION   251 non-null    object
#  51  Shape_Leng  251 non-null    float64
#  52  Shape_Area  251 non-null    float64
#  53  geometry    251 non-null    geometry
# dtypes: float64(3), geometry(1), int64(8), object(42)
# memory usage: 106.0+ KB

# %% [markdown]
# You know you have a geodataframe when you have a **geometry column type**.

# %%
worldmap.geometry
# Out:
# 0      MULTIPOLYGON (((117.70361 4.16341, 117.83855 4...
# 1      MULTIPOLYGON (((117.70361 4.16341, 117.90704 4...
# 2      MULTIPOLYGON (((-69.51009 -17.50659, -69.68390...
# 3      POLYGON ((-69.51009 -17.50659, -69.49712 -17.6...
# 4      MULTIPOLYGON (((-69.51009 -17.50659, -69.52260...
#                              ...
# 246    POLYGON ((-75.02432 18.41726, -75.01781 18.396...
# 247    POLYGON ((-162.06086 5.88719, -162.07136 5.890...
# 248    POLYGON ((-162.40018 6.44514, -162.40018 6.430...
# 249    MULTIPOLYGON (((-171.18566 -9.36126, -171.1913...
# 250    MULTIPOLYGON (((169.21276 -52.47456, 169.14431...
# Name: geometry, Length: 251, dtype: geometry

# %% [markdown]
# This data frame has several columns. Using **head()** is important to detect salient problems, but pandas or geopandas may hide some columns:

# %%
worldmap.head()
# Out:
#    FID  OBJECTID       featurecla  LEVEL               TYPE  \
# 0    0         1  Admin-0 country      2  Sovereign country
# 1    1         2  Admin-0 country      2  Sovereign country
# 2    2         3  Admin-0 country      2  Sovereign country
# 3    3         4  Admin-0 country      2  Sovereign country
# 4    4         5  Admin-0 country      2  Sovereign country
#
#                         FORMAL_EN FORMAL_FR    POP_EST  POP_RANK  GDP_MD_EST  \
# 0           Republic of Indonesia            260580739        17   3028000.0
# 1                        Malaysia             31381992        15    863000.0
# 2               Republic of Chile             17789267        14    436100.0
# 3  Plurinational State of Bolivia             11138234        14     78350.0
# 4                Republic of Peru             31036656        15    410400.0
#
#    ...     NAME_SV    NAME_TR    NAME_VI NAME_ZH    WB_NAME WB_RULES  \
# 0  ...  Indonesien  Endonezya  Indonesia   ?????  Indonesia     None
# 1  ...    Malaysia    Malezya   Malaysia    ????   Malaysia     None
# 2  ...       Chile       ?ili      Chile      ??      Chile     None
# 3  ...     Bolivia    Bolivya    Bolivia    ????    Bolivia     None
# 4  ...        Peru       Peru       Peru      ??       Peru     None
#
#   WB_REGION  Shape_Leng  Shape_Area  \
# 0       EAP  495.029918  153.078608
# 1       EAP   68.456913   26.703172
# 2       LCR  416.997272   76.761813
# 3       LCR   54.345991   92.203587
# 4       LCR   73.262192  106.417089
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.83855 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.90704 4...
# 2  MULTIPOLYGON (((-69.51009 -17.50659, -69.68390...
# 3  POLYGON ((-69.51009 -17.50659, -69.49712 -17.6...
# 4  MULTIPOLYGON (((-69.51009 -17.50659, -69.52260...
#
# [5 rows x 54 columns]

# %% [markdown]
# An strategy would be to see the head as an **html**:

# %%
from IPython.core.display import HTML

display(HTML(worldmap.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FID</th>
#       <th>OBJECTID</th>
#       <th>featurecla</th>
#       <th>LEVEL</th>
#       <th>TYPE</th>
#       <th>FORMAL_EN</th>
#       <th>FORMAL_FR</th>
#       <th>POP_EST</th>
#       <th>POP_RANK</th>
#       <th>GDP_MD_EST</th>
#       <th>POP_YEAR</th>
#       <th>LASTCENSUS</th>
#       <th>GDP_YEAR</th>
#       <th>ECONOMY</th>
#       <th>INCOME_GRP</th>
#       <th>FIPS_10_</th>
#       <th>ISO_A2</th>
#       <th>ISO_A3</th>
#       <th>ISO_A3_EH</th>
#       <th>ISO_N3</th>
#       <th>UN_A3</th>
#       <th>WB_A2</th>
#       <th>WB_A3</th>
#       <th>CONTINENT</th>
#       <th>REGION_UN</th>
#       <th>SUBREGION</th>
#       <th>REGION_WB</th>
#       <th>NAME_AR</th>
#       <th>NAME_BN</th>
#       <th>NAME_DE</th>
#       <th>NAME_EN</th>
#       <th>NAME_ES</th>
#       <th>NAME_FR</th>
#       <th>NAME_EL</th>
#       <th>NAME_HI</th>
#       <th>NAME_HU</th>
#       <th>NAME_ID</th>
#       <th>NAME_IT</th>
#       <th>NAME_JA</th>
#       <th>NAME_KO</th>
#       <th>NAME_NL</th>
#       <th>NAME_PL</th>
#       <th>NAME_PT</th>
#       <th>NAME_RU</th>
#       <th>NAME_SV</th>
#       <th>NAME_TR</th>
#       <th>NAME_VI</th>
#       <th>NAME_ZH</th>
#       <th>WB_NAME</th>
#       <th>WB_RULES</th>
#       <th>WB_REGION</th>
#       <th>Shape_Leng</th>
#       <th>Shape_Area</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Republic of Indonesia</td>
#       <td></td>
#       <td>260580739</td>
#       <td>17</td>
#       <td>3028000.0</td>
#       <td>2017</td>
#       <td>2010</td>
#       <td>2016</td>
#       <td>4. Emerging region: MIKT</td>
#       <td>4. Lower middle income</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>IDN</td>
#       <td>IDN</td>
#       <td>360</td>
#       <td>360</td>
#       <td>ID</td>
#       <td>IDN</td>
#       <td>Asia</td>
#       <td>Asia</td>
#       <td>South-Eastern Asia</td>
#       <td>East Asia &amp; Pacific</td>
#       <td>?????????</td>
#       <td>????????????</td>
#       <td>Indonesien</td>
#       <td>Indonesia</td>
#       <td>Indonesia</td>
#       <td>Indonésie</td>
#       <td>?????????</td>
#       <td>??????????</td>
#       <td>Indonézia</td>
#       <td>Indonesia</td>
#       <td>Indonesia</td>
#       <td>??????</td>
#       <td>?????</td>
#       <td>Indonesië</td>
#       <td>Indonezja</td>
#       <td>Indonésia</td>
#       <td>?????????</td>
#       <td>Indonesien</td>
#       <td>Endonezya</td>
#       <td>Indonesia</td>
#       <td>?????</td>
#       <td>Indonesia</td>
#       <td>None</td>
#       <td>EAP</td>
#       <td>495.029918</td>
#       <td>153.078608</td>
#       <td>MULTIPOLYGON (((117.70361 4.16341, 117.83855 4.04019, 117.93483 4.05988, 117.90704 4.15668, 117.70361 4.16341)), ((124.45053 -9.18019, 124.42794 -9.29948, 124.34789 -9.37462, 124.31007 -9.48872, 124.25751 -9.50123, 124.21069 -9.37886, 124.12108 -9.42692, 124.01010 -9.34393, 123.68881 -9.61142, 123.64332 -9.78281, 123.66041 -9.87127, 123.58375 -9.94402, 123.57740 -10.03436, 123.60564 -10.05429, 123.68434 -10.02500, 123.76466 -10.07497, 123.51539 -10.21307, 123.47202 -10.36492, 123.53647 -10.33196, 123.61744 -10.36631, 123.79933 -10.37469, 123.93279 -10.29485, 124.03386 -10.27614, 124.12241 -10.17254, 124.38087 -10.17051, 124.49936 -10.11199, 124.56031 -10.01523, 124.73455 -9.89951, 124.84693 -9.74822, 124.97975 -9.64902, 125.00196 -9.53631, 125.06162 -9.48577, 125.02341 -9.34558, 124.96599 -9.29339, 124.95793 -9.21194, 125.15063 -9.18538, 125.16236 -9.06063, 125.08681 -8.98622, 125.05183 -9.03500, 124.93302 -9.07448, 124.90791 -9.03748, 124.91951 -8.96202, 124.68800 -9.06951, 124.60434 -9.15635, 124.45053 -9.18019)), ((117.56715 4.15965, 117.43648 4.18561, 117.20270 4.35607, 117.16466 4.33315, 116.80448 4.33007, 116.71167 4.36679, 116.59023 4.33113, 116.52222 4.39679, 116.49411 4.32485, 116.41132 4.28865, 116.31066 4.38338, 116.22880 4.35612, 116.12576 4.37891, 116.02065 4.27085, 115.97724 4.32863, 115.84412 4.38922, 115.77074 4.22561, 115.73260 4.23938, 115.64693 4.16910, 115.60951 3.99691, 115.53882 3.92061, 115.58863 3.85760, 115.54440 3.62916, 115.60124 3.43023, 115.55721 3.42545, 115.51763 3.35716, 115.48280 3.20647, 115.51701 3.15728, 115.46409 3.03082, 115.30999 2.98592, 115.24209 3.04162, 115.06908 2.83264, 115.10463 2.76149, 115.05699 2.71126, 115.05647 2.60863, 115.15197 2.59705, 115.20613 2.50987, 114.97296 2.35748, 114.92221 2.35391, 114.91333 2.28405, 114.77876 2.24720, 114.75303 2.13481, 114.78062 2.03605, 114.84108 2.03822, 114.83199 1.90252, 114.67954 1.84074, 114.66900 1.69401, 114.56317 1.53639, 114.54560 1.43495, 114.37486 1.50694, 114.17342 1.42051, 114.09426 1.46567, 113.90967 1.44247, 113.80817 1.33971, 113.62483 1.22757, 113.52447 1.31356, 113.39755 1.29393, 113.32366 1.35139, 113.08905 1.43133, 112.95820 1.41565, 113.02435 1.51438, 112.97319 1.56985, 112.85495 1.58272, 112.80152 1.54378, 112.47048 1.56766, 112.16156 1.43454, 112.18739 1.37966, 112.09293 1.14314, 111.91010 1.11404, 111.82308 1.00847, 111.76282 0.99302, 111.62267 1.03027, 111.50320 0.95844, 111.47209 1.02221, 111.37411 1.00754, 111.19758 1.07523, 110.88039 1.01053, 110.77673 0.90325, 110.66129 0.87214, 110.61343 0.89395, 110.55390 0.85137, 110.46026 0.87974, 110.36415 0.98139, 110.26348 0.99431, 110.17036 1.17445, 110.05181 1.21548, 109.96376 1.29858, 109.92025 1.39477, 109.84283 1.40327, 109.65804 1.59719, 109.64181 1.78100, 109.55562 1.80217, 109.52844 1.88999, 109.64527 2.08324, 109.57887 1.99763, 109.34099 1.93553, 109.33513 1.85017, 109.28679 1.77823, 109.34783 1.80956, 109.27223 1.69379, 109.07301 1.53392, 109.05437 1.35224, 108.98585 1.21581, 109.13738 1.26227, 109.24049 1.40420, 109.26637 1.39460, 109.14283 1.25064, 108.92433 1.16401, 108.98080 0.95604, 108.94142 0.88402, 108.85548 0.83222, 108.93116 0.61620, 108.91000 0.53059, 108.94435 0.42251, 108.92091 0.34028, 109.10231 0.24311, 109.16676 0.11229, 109.30047 0.01048, 109.15650 0.02009, 109.19060 -0.18873, 109.22478 -0.23724, 109.11866 -0.20306, 109.04623 -0.24586, 109.06707 -0.27125, 109.10133 -0.25758, 109.13600 -0.36004, 109.10060 -0.36972, 109.13941 -0.52858, 109.26238 -0.59246, 109.40065 -0.59734, 109.42408 -0.62021, 109.35515 -0.61395, 109.35515 -0.64813, 109.50652 -0.71640, 109.46860 -0.73707, 109.26254 -0.66741, 109.27320 -0.85361, 109.39080 -0.91188, 109.41896 -0.90358, 109.42799 -0.84661, 109.52565 -0.86240, 109.58172 -0.89446, 109.60524 -0.95664, 109.67726 -0.98382, 109.72438 -0.88877, 109.76352 -0.87086, 109.74049 -0.96754, 109.83546 -1.08620, 109.93458 -1.11256, 109.92986 -1.22324, 110.02955 -1.28590, 110.06137 -1.34637, 110.03395 -1.64617, 109.99391 -1.73 ...

# %% [markdown]
# The geometry column does not allow a clean visual of the data. Let's omit it and redo the previous code:

# %%
display(HTML(worldmap.drop(columns='geometry').to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FID</th>
#       <th>OBJECTID</th>
#       <th>featurecla</th>
#       <th>LEVEL</th>
#       <th>TYPE</th>
#       <th>FORMAL_EN</th>
#       <th>FORMAL_FR</th>
#       <th>POP_EST</th>
#       <th>POP_RANK</th>
#       <th>GDP_MD_EST</th>
#       <th>POP_YEAR</th>
#       <th>LASTCENSUS</th>
#       <th>GDP_YEAR</th>
#       <th>ECONOMY</th>
#       <th>INCOME_GRP</th>
#       <th>FIPS_10_</th>
#       <th>ISO_A2</th>
#       <th>ISO_A3</th>
#       <th>ISO_A3_EH</th>
#       <th>ISO_N3</th>
#       <th>UN_A3</th>
#       <th>WB_A2</th>
#       <th>WB_A3</th>
#       <th>CONTINENT</th>
#       <th>REGION_UN</th>
#       <th>SUBREGION</th>
#       <th>REGION_WB</th>
#       <th>NAME_AR</th>
#       <th>NAME_BN</th>
#       <th>NAME_DE</th>
#       <th>NAME_EN</th>
#       <th>NAME_ES</th>
#       <th>NAME_FR</th>
#       <th>NAME_EL</th>
#       <th>NAME_HI</th>
#       <th>NAME_HU</th>
#       <th>NAME_ID</th>
#       <th>NAME_IT</th>
#       <th>NAME_JA</th>
#       <th>NAME_KO</th>
#       <th>NAME_NL</th>
#       <th>NAME_PL</th>
#       <th>NAME_PT</th>
#       <th>NAME_RU</th>
#       <th>NAME_SV</th>
#       <th>NAME_TR</th>
#       <th>NAME_VI</th>
#       <th>NAME_ZH</th>
#       <th>WB_NAME</th>
#       <th>WB_RULES</th>
#       <th>WB_REGION</th>
#       <th>Shape_Leng</th>
#       <th>Shape_Area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Republic of Indonesia</td>
#       <td></td>
#       <td>260580739</td>
#       <td>17</td>
#       <td>3028000.00</td>
#       <td>2017</td>
#       <td>2010</td>
#       <td>2016</td>
#       <td>4. Emerging region: MIKT</td>
#       <td>4. Lower middle income</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>IDN</td>
#       <td>IDN</td>
#       <td>360</td>
#       <td>360</td>
#       <td>ID</td>
#       <td>IDN</td>
#       <td>Asia</td>
#       <td>Asia</td>
#       <td>South-Eastern Asia</td>
#       <td>East Asia &amp; Pacific</td>
#       <td>?????????</td>
#       <td>????????????</td>
#       <td>Indonesien</td>
#       <td>Indonesia</td>
#       <td>Indonesia</td>
#       <td>Indonésie</td>
#       <td>?????????</td>
#       <td>??????????</td>
#       <td>Indonézia</td>
#       <td>Indonesia</td>
#       <td>Indonesia</td>
#       <td>??????</td>
#       <td>?????</td>
#       <td>Indonesië</td>
#       <td>Indonezja</td>
#       <td>Indonésia</td>
#       <td>?????????</td>
#       <td>Indonesien</td>
#       <td>Endonezya</td>
#       <td>Indonesia</td>
#       <td>?????</td>
#       <td>Indonesia</td>
#       <td>None</td>
#       <td>EAP</td>
#       <td>495.029918</td>
#       <td>153.078608</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Malaysia</td>
#       <td></td>
#       <td>31381992</td>
#       <td>15</td>
#       <td>863000.00</td>
#       <td>2017</td>
#       <td>2010</td>
#       <td>2016</td>
#       <td>6. Developing region</td>
#       <td>3. Upper middle income</td>
#       <td>MY</td>
#       <td>MY</td>
#       <td>MYS</td>
#       <td>MYS</td>
#       <td>458</td>
#       <td>458</td>
#       <td>MY</td>
#       <td>MYS</td>
#       <td>Asia</td>
#       <td>Asia</td>
#       <td>South-Eastern Asia</td>
#       <td>East Asia &amp; Pacific</td>
#       <td>???????</td>
#       <td>???????????</td>
#       <td>Malaysia</td>
#       <td>Malaysia</td>
#       <td>Malasia</td>
#       <td>Malaisie</td>
#       <td>????????</td>
#       <td>???????</td>
#       <td>Malajzia</td>
#       <td>Malaysia</td>
#       <td>Malesia</td>
#       <td>?????</td>
#       <td>?????</td>
#       <td>Maleisië</td>
#       <td>Malezja</td>
#       <td>Malásia</td>
#       <td>????????</td>
#       <td>Malaysia</td>
#       <td>Malezya</td>
#       <td>Malaysia</td>
#       <td>????</td>
#       <td>Malaysia</td>
#       <td>None</td>
#       <td>EAP</td>
#       <td>68.456913</td>
#       <td>26.703172</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>3</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Republic of Chile</td>
#       <td></td>
#       <td>17789267</td>
#       <td>14</td>
#       <td>436100.00</td>
#       <td>2017</td>
#       <td>2002</td>
#       <td>2016</td>
#       <td>5. Emerging region: G20</td>
#       <td>3. Upper middle income</td>
#       <td>CI</td>
#       <td>CL</td>
#       <td>CHL</td>
#       <td>CHL</td>
#       <td>152</td>
#       <td>152</td>
#       <td>CL</td>
#       <td>CHL</td>
#       <td>South America</td>
#       <td>Americas</td>
#       <td>South America</td>
#       <td>Latin America &amp; Caribbean</td>
#       <td>?????</td>
#       <td>????</td>
#       <td>Chile</td>
#       <td>Chile</td>
#       <td>Chile</td>
#       <td>Chili</td>
#       <td>????</td>
#       <td>????</td>
#       <td>Chile</td>
#       <td>Chili</td>
#       <td>Cile</td>
#       <td>??</td>
#       <td>??</td>
#       <td>Chili</td>
#       <td>Chile</td>
#       <td>Chile</td>
#       <td>????</td>
#       <td>Chile</td>
#       <td>?ili</td>
#       <td>Chile</td>
#       <td>??</td>
#       <td>Chile</td>
#       <td>None</td>
#       <td>LCR</td>
#       <td>416.997272</td>
#       <td>76.761813</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>4</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Plurinational State of Bolivia</td>
#       <td></td>
#       <td>11138234</td>
#       <td>14</td>
#       <td>78350.00</td>
#       <td>2017</td>
#       <td>2001</td>
#       <td>2016</td>
#       <td>5. Emerging region: G20</td>
#       <td>4. Lower middle income</td>
#       <td>BL</td>
#       <td>BO</td>
#       <td>BOL</td>
#       <td>BOL</td>
#       <td>068</td>
#       <td>068</td>
#       <td>BO</td>
#       <td>BOL</td>
#       <td>South America</td>
#       <td>Americas</td>
#       <td>South America</td>
#       <td>Latin America &amp; Caribbean</td>
#       <td>???????</td>
#       <td>????????</td>
#       <td>Bolivien</td>
#       <td>Bolivia</td>
#       <td>Bolivia</td>
#       <td>Bolivie</td>
#       <td>???????</td>
#       <td>????????</td>
#       <td>Bolívia</td>
#       <td>Bolivia</td>
#       <td>Bolivia</td>
#       <td>????</td>
#       <td>????</td>
#       <td>Bolivia</td>
#       <td>Boliwia</td>
#       <td>Bolívia</td>
#       <td>???????</td>
#       <td>Bolivia</td>
#       <td>Bolivya</td>
#       <td>Bolivia</td>
#       <td>????</td>
#       <td>Bolivia</td>
#       <td>None</td>
#       <td>LCR</td>
#       <td>54.345991</td>
#       <td>92.203587</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>5</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Republic of Peru</td>
#       <td></td>
#       <td>31036656</td>
#       <td>15</td>
#       <td>410400.00</td>
#       <td>2017</td>
#       <td>2007</td>
#       <td>2016</td>
#       <td>5. Emerging region: G20</td>
#       <td>3. Upper middle income</td>
#       <td>PE</td>
#       <td>PE</td>
#       <td>PER</td>
#       <td>PER</td>
#       <td>604</td>
#       <td>604</td>
#       <td>PE</td>
#       <td>PER</td>
#       <td>South America</td>
#       <td>Americas</td>
#       <td>South America</td>
#       <td>Latin America &amp; Caribbean</td>
#       <td>????</td>
#       <td>????</td>
#       <td>Peru</td>
#       <td>Peru</td>
#       <td>Perú</td>
#       <td>Pérou</td>
#       <td>?????</td>
#       <td>????</td>
#       <td>Peru</td>
#       <td>Peru</td>
#       <td>Perù</td>
#       <td>???</td>
#       <td>??</td>
#       <td>Peru</td>
#       <td>Peru</td>
#       <td>Peru</td>
#       <td>????</td>
#       <td>Peru</td>
#       <td>Peru</td>
#       <td>Peru</td>
#       <td>??</td>
#       <td>Peru</td>
#       <td>None</td>
#       <td>LCR</td>
#       <td>73.262192</td>
#       <td>106.417089</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>6</td>
#       <td>Admin-0 country</td>
#       <td>2</td>
#       <td>Sovereign country</td>
#       <td>Argentine Republic</td>
#       <td></td>
#       <td>44293293</td>
#       <td>15</td>
#       <td>879400.00</td>
#       <td>2017</td>
#       <td>2010</td>
#       <td>2016</td>
#       <td>5. Emerging region: G20</td>

# %% [markdown]
# There are so many columns, it may be very hard to check each one for particular problems. In general, you need a clean map where you can add other data to it. The most important imformation will be in the data you add.
# Then, in this case, you will pay attention to the columns that are needed to combine this map and other data; that is, verify that the **key** or **identifiers** are clean. Let's see:

# %%
# any missin values?
worldmap[worldmap.isna().any(axis=1)]
# Out:
# Empty GeoDataFrame
# Columns: [FID, OBJECTID, featurecla, LEVEL, TYPE, FORMAL_EN, FORMAL_FR, POP_EST, POP_RANK, GDP_MD_EST, POP_YEAR, LASTCENSUS, GDP_YEAR, ECONOMY, INCOME_GRP, FIPS_10_, ISO_A2, ISO_A3, ISO_A3_EH, ISO_N3, UN_A3, WB_A2, WB_A3, CONTINENT, REGION_UN, SUBREGION, REGION_WB, NAME_AR, NAME_BN, NAME_DE, NAME_EN, NAME_ES, NAME_FR, NAME_EL, NAME_HI, NAME_HU, NAME_ID, NAME_IT, NAME_JA, NAME_KO, NAME_NL, NAME_PL, NAME_PT, NAME_RU, NAME_SV, NAME_TR, NAME_VI, NAME_ZH, WB_NAME, WB_RULES, WB_REGION, Shape_Leng, Shape_Area, geometry]
# Index: []
#
# [0 rows x 54 columns]

# %% [markdown]
# From the data frame head, you may use these as identifiers of the rows:

# %%
identifiers=['TYPE','FORMAL_EN','FIPS_10_','ISO_A2', 'ISO_A3',"ISO_A3_EH"]
worldmap.loc[:,identifiers]
# Out:
#                   TYPE                       FORMAL_EN FIPS_10_ ISO_A2 ISO_A3  \
# 0    Sovereign country           Republic of Indonesia       ID     ID    IDN
# 1    Sovereign country                        Malaysia       MY     MY    MYS
# 2    Sovereign country               Republic of Chile       CI     CL    CHL
# 3    Sovereign country  Plurinational State of Bolivia       BL     BO    BOL
# 4    Sovereign country                Republic of Peru       PE     PE    PER
# ..                 ...                             ...      ...    ...    ...
# 246         Dependency                                      -99     UM    UMI
# 247         Dependency                                      -99     UM    UMI
# 248         Dependency                                      -99     UM    UMI
# 249            Country                     New Zealand       NZ     NZ    NZL
# 250            Country                     New Zealand       NZ     NZ    NZL
#
#     ISO_A3_EH
# 0         IDN
# 1         MYS
# 2         CHL
# 3         BOL
# 4         PER
# ..        ...
# 246       UMI
# 247       UMI
# 248       UMI
# 249       NZL
# 250       NZL
#
# [251 rows x 6 columns]

# %%
# any repeated values in country name ('FORMAL_EN')?

worldmap[worldmap.duplicated(subset=['FORMAL_EN'],keep=False)].drop(columns='geometry')
# Out:
#      FID  OBJECTID       featurecla  LEVEL               TYPE  \
# 129  129       130  Admin-0 country      2              Lease
# 148  148       149  Admin-0 country      2         Dependency
# 189  189       190  Admin-0 country      2         Dependency
# 195  195       196  Admin-0 country      2         Dependency
# 201  201       202  Admin-0 country      2         Dependency
# 209  209       210  Admin-0 country      2            Country
# 211  211       212  Admin-0 country      2         Dependency
# 214  214       215  Admin-0 country      2         Dependency
# 218  218       219  Admin-0 country      2  Sovereign country
# 226  226       227  Admin-0 country      2         Dependency
# 232  232       233  Admin-0 country      2         Dependency
# 234  234       235  Admin-0 country      2            Country
# 235  235       236  Admin-0 country      2            Country
# 236  236       237  Admin-0 country      2            Country
# 237  237       238  Admin-0 country      2            Country
# 238  238       239  Admin-0 country      2         Dependency
# 239  239       240  Admin-0 country      2         Dependency
# 240  240       241  Admin-0 country      2         Dependency
# 241  241       242  Admin-0 country      2         Dependency
# 242  242       243  Admin-0 country      2         Dependency
# 243  243       244  Admin-0 country      2         Dependency
# 244  244       245  Admin-0 country      2         Dependency
# 245  245       246  Admin-0 country      2         Dependency
# 246  246       247  Admin-0 country      2         Dependency
# 247  247       248  Admin-0 country      2         Dependency
# 248  248       249  Admin-0 country      2         Dependency
# 249  249       250  Admin-0 country      2            Country
# 250  250       251  Admin-0 country      2            Country
#
#                       FORMAL_EN FORMAL_FR   POP_EST  POP_RANK  GDP_MD_EST  \
# 129                                            7000         5      280.00
# 148                                           29396         7     2044.00
# 189                                            5292         5       43.80
# 195                                           17087         6      175.40
# 201                                            7828         5       31.10
# 209                                           88815         8     7428.00
# 211                                            4000         4      160.00
# 214                                            9290         5      244.10
# 218                                          647581        11     1198.00
# 226                                            1626         3       10.00
# 232                                               0         1        0.00
# 234  Kingdom of the Netherlands            17084719        14   870800.00
# 235  Kingdom of the Netherlands            17084719        14   870800.00
# 236  Kingdom of the Netherlands            17084719        14   870800.00
# 237  Kingdom of the Netherlands            17084719        14   870800.00
# 238                                            2801         4       42.02
# 239                                            2801         4       42.02
# 240                                             300         2        0.00
# 241                                             300         2        0.00
# 242                                             300         2        0.00
# 243                                             300         2        0.00
# 244                                             300         2        0.00
# 245                                             300         2        0.00
# 246                                             300         2        0.00
# 247                                             300         2        0.00
# 248                                             300         2        0.00
# 249                 New Zealand             4510327        12   174800.00
# 250                 New Zealand             4510327        12   174800.00
#
#      ...                                      NAME_RU  \
# 129  ...                      ??????? ???? ??????????
# 148  ...                                    ?????????
# 189  ...                                   ??????????
# 195  ...                                      ???????
# 201  ...                          ?????? ?????? ?????
# 209  ...                                   ?????? ???
# 211  ...     ?????????? ?????????? ? ????????? ??????
# 214  ...                                 ??????? ????
# 218  ...                           ?????????? ???????
# 226  ...                                         ????
# 232  ...                                   ??????????
# 234  ...                                   ??????????
# 235  ...                                   ??????????
# 236  ...                                   ??????????
# 237  ...                                   ??????????
# 238  ...  ????????????? ?????????? ? ????????? ??????
# 239  ...  ????????????? ?????????? ? ????????? ??????
# 240  ...                    ??????? ????? ??????? ???
# 241  ...                    ??????? ????? ??????? ???
# 242  ...                    ??????? ????? ??????? ???
# 243  ...                    ??????? ????? ??????? ???
# 244  ...                    ??????? ????? ??????? ???
# 245  ...                    ??????? ????? ??????? ???
# 246  ...                    ??????? ????? ??????? ???
# 247  ...                    ??????? ????? ??????? ???
# 248  ...                    ??????? ????? ??????? ???
# 249  ...                               ????? ????????
# 250  ...                               ????? ????????
#
#                                                NAME_SV  \
# 129                                    Guantánamobasen
# 148                                          Gibraltar
# 189                                         Montserrat
# 195                                           Anguilla
# 201                                      Sankta Helena
# 209                                        Isle of Man
# 211            Brittiska territoriet i Indiska oceanen
# 214                                          Cooköarna
# 218                                       Salomonöarna
# 226                                               Niue
# 232                                       Clippertonön
# 234                                      Nederländerna
# 235                                      Nederländerna
# 236                                      Nederländerna
# 237                                      Nederländerna
# 238          Australienska indiska oceanens havsområde
# 239          Australienska indiska oceanens havsområde
# 240  Förenta staternas mindre öar i Oceanien och Vä...
# 241  Förenta staternas mindre öar i Oceanien och Vä...
# 242  Förenta staternas mindre öar i Oceanien och Vä...
# 243  Förenta staternas mindre öar i Oceanien och Vä...
# 244  Förenta staternas mindre öar i Oceanien och Vä...
# 245  Förenta staternas mindre öar i Oceanien och Vä...
# 246  Förenta staternas mindre öar i Oceanien och Vä...
# 247  Förenta staternas mindre öar i Oceanien och Vä...
# 248  Förenta staternas mindre öar i Oceanien och Vä...
# 249                                        Nya Zeeland
# 250                                        Nya Zeeland
#
#                                   NAME_TR                             NAME_VI  \
# 129                        Guantanamo Bay     C?n c? H?i quân v?nh Guantánamo
# 148                           Cebelitar?k                           Gibraltar
# 189                            Montserrat                          Montserrat
# 195                              Anguilla                            Anguilla
# 201                          Saint Helena                        Saint Helena
# 209                             Man Adas?                             ??o Man
# 211     Britanya Hint Okyanusu Topraklar?      Lãnh th? ?n ?? D??ng thu?c Anh
# 214                          Cook Adalar?                       Qu?n ??o Cook
# 218                       Solomon Adalar?                    Qu?n ??o Solomon
# 226                                  Niue                                Niue
# 232                      Clipperton Adas?                          Clipperton
# 234                              Hollanda                              Hà Lan
# 235                              Hollanda                              Hà Lan
# 236                              Hollanda                              Hà Lan
# 237                              Hollanda                              Hà Lan
# 238   Australian Indian Ocean Territories  Vùng lãnh th? ?n ?? D??ng thu?c Úc
# 239   Australian Indian Ocean Territories  Vùng lãnh th? ?n ?? D??ng thu?c Úc
# 240  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 241  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 242  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 243  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 244  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 245  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 246  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 247  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 248  United States Minor Outlying Islands          Các ti?u ??o xa c?a Hoa K?
# 249                          Yeni Zelanda                         New Zealand
# 250                          Yeni Zelanda                         New Zealand
#
#       NAME_ZH                                            WB_NAME  \
# 129                                          Guantanamo Bay (US)
# 148      ????                                     Gibraltar (UK)
# 189     ?????                                    Montserrat (UK)
# 195       ???                                      Anguilla (UK)
# 201     ?????  Saint Helena, Ascension and Tristan da Cunha (UK)
# 209       ???                                   Isle of Man (UK)
# 211   ???????                British Indian Ocean Territory (UK)
# 214      ????                                  Cook Islands (NZ)
# 218     ?????                                    Solomon Islands
# 226        ??                                          Niue (NZ)
# 232     ?????                            Clipperton Island (Fr.)
# 234        ??                                    Bonaire (Neth.)
# 235        ??                             Sint Eustatius (Neth.)
# 236        ??                                       Saba (Neth.)
# 237        ??                                        Netherlands
# 238   ???????                     Cocos (Keeling) Islands (Aus.)
# 239   ???????                            Christmas Island (Aus.)
# 240  ????????                                Johnston Atoll (US)
# 241  ????????                                 Jarvis Island (US)
# 242  ????????                                  Baker Island (US)
# 243  ????????                                Howland Island (US)
# 244  ????????                                   Wake Island (US)
# 245  ????????                                Midway Islands (US)
# 246  ????????                                Navassa Island (US)
# 247  ????????                                 Palmyra Atoll (US)
# 248  ????????                                  Kingman Reef (US)
# 249       ???                                       Tokelau (NZ)
# 250       ???                                        New Zealand
#
#            WB_RULES WB_REGION  Shape_Leng Shape_Area
# 129  Name in italic     Other    0.657742   0.005639
# 148  Name in italic     Other    0.085999   0.000370
# 189  Name in italic     Other    0.384947   0.008440
# 195  Name in italic     Other    0.506124   0.006891
# 201  Name in italic     Other    1.489643   0.033666
# 209  Name in italic     Other    1.409961   0.079186
# 211  Name in italic     Other    1.171956   0.004016
# 214  Name in italic     Other    1.764192   0.016506
# 218            None       EAP   40.721515   2.236402
# 226  Name in italic     Other    0.581958   0.018931
# 232  Name in italic     Other    0.081190   0.000413
# 234  Name in italic     Other    0.870961   0.022355
# 235  Name in italic     Other    0.178178   0.001619
# 236  Name in italic     Other    0.090968   0.000601
# 237            None     Other   22.816386   4.884540
# 238  Name in italic     Other    0.318738   0.001097
# 239  Name in italic     Other    0.489928   0.008153
# 240  Name in italic     Other    0.113208   0.000208
# 241  Name in italic     Other    0.059294   0.000190
# 242  Name in italic     Other    0.046053   0.000058
# 243  Name in italic     Other    0.035559   0.000039
# 244  Name in italic     Other    0.108125   0.000337
# 245  Name in italic     Other    0.110434   0.000322
# 246  Name in italic     Other    0.085608   0.000413
# 247  Name in italic     Other    0.147363   0.000576
# 248  Name in italic     Other    0.059570   0.000222
# 249  Name in italic     Other    0.178453   0.000348
# 250            None     Other  104.828986  29.143542
#
# [28 rows x 53 columns]

# %% [markdown]
# This is a nice case of repeated values. Why would a map of countries repeat country names?
# Our first **guess** is that each row represents a polygon (a surface on the planet), so maybe a country may be composed of several polygons. But, we already saw the presence of **multipolygons** in a row. Then, it is possible that some polygons are differentiated for some international politics reason.
#
# In order to find out the nature of these findings we might need a closer look to the data. Let's use [dtale](https://github.com/man-group/dtale)

# %%
from dtale import show as dtshow


dtshow(worldmap[worldmap.duplicated(subset=['FORMAL_EN'],keep=False)].drop(columns='geometry'))
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://JoseManuels-MacBook-Pro.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# As you see, the map data is not perfect because of the complexity of international laws and the like. Notice the presence of "-99" and "-099". Those are representing a missing value. You may want to keep it that way as some map formats may not work as expected with missing values.
#
# Let's update our identifiers and create a new map:

# %%
identifiers=['TYPE','FORMAL_EN','WB_NAME','NAME_EN','FIPS_10_','ISO_A2', 'ISO_A3',"ISO_A3_EH",'ISO_N3','UN_A3',"WB_A2",'WB_A3','geometry']
mapWorld=worldmap.loc[:,identifiers]

#then
mapWorld[mapWorld.duplicated(subset=['FORMAL_EN'],keep=False)].drop(columns='geometry')
# Out:
#                   TYPE                   FORMAL_EN  \
# 129              Lease
# 148         Dependency
# 189         Dependency
# 195         Dependency
# 201         Dependency
# 209            Country
# 211         Dependency
# 214         Dependency
# 218  Sovereign country
# 226         Dependency
# 232         Dependency
# 234            Country  Kingdom of the Netherlands
# 235            Country  Kingdom of the Netherlands
# 236            Country  Kingdom of the Netherlands
# 237            Country  Kingdom of the Netherlands
# 238         Dependency
# 239         Dependency
# 240         Dependency
# 241         Dependency
# 242         Dependency
# 243         Dependency
# 244         Dependency
# 245         Dependency
# 246         Dependency
# 247         Dependency
# 248         Dependency
# 249            Country                 New Zealand
# 250            Country                 New Zealand
#
#                                                WB_NAME  \
# 129                                Guantanamo Bay (US)
# 148                                     Gibraltar (UK)
# 189                                    Montserrat (UK)
# 195                                      Anguilla (UK)
# 201  Saint Helena, Ascension and Tristan da Cunha (UK)
# 209                                   Isle of Man (UK)
# 211                British Indian Ocean Territory (UK)
# 214                                  Cook Islands (NZ)
# 218                                    Solomon Islands
# 226                                          Niue (NZ)
# 232                            Clipperton Island (Fr.)
# 234                                    Bonaire (Neth.)
# 235                             Sint Eustatius (Neth.)
# 236                                       Saba (Neth.)
# 237                                        Netherlands
# 238                     Cocos (Keeling) Islands (Aus.)
# 239                            Christmas Island (Aus.)
# 240                                Johnston Atoll (US)
# 241                                 Jarvis Island (US)
# 242                                  Baker Island (US)
# 243                                Howland Island (US)
# 244                                   Wake Island (US)
# 245                                Midway Islands (US)
# 246                                Navassa Island (US)
# 247                                 Palmyra Atoll (US)
# 248                                  Kingman Reef (US)
# 249                                       Tokelau (NZ)
# 250                                        New Zealand
#
#                                   NAME_EN FIPS_10_ ISO_A2 ISO_A3 ISO_A3_EH  \
# 129             Guantanamo Bay Naval Base      -99    -99    -99       -99
# 148                             Gibraltar       GI     GI    GIB       GIB
# 189                            Montserrat       MH     MS    MSR       MSR
# 195                              Anguilla       AV     AI    AIA       AIA
# 201                          Saint Helena       SH     SH    SHN       SHN
# 209                           Isle of Man       IM     IM    IMN       IMN
# 211        British Indian Ocean Territory       IO     IO    IOT       IOT
# 214                          Cook Islands       CW     CK    COK       COK
# 218                       Solomon Islands       BP     SB    SLB       SLB
# 226                                  Niue       NE     NU    NIU       NIU
# 232                     Clipperton Island       IP    -99    -99       -99
# 234                           Netherlands       NL     NL    NLD       NLD
# 235                           Netherlands       NL     NL    NLD       NLD
# 236                           Netherlands       NL     NL    NLD       NLD
# 237                           Netherlands       NL     NL    NLD       NLD
# 238   Australian Indian Ocean Territories      -99    -99    -99       -99
# 239   Australian Indian Ocean Territories      -99    -99    -99       -99
# 240  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 241  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 242  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 243  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 244  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 245  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 246  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 247  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 248  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 249                           New Zealand       NZ     NZ    NZL       NZL
# 250                           New Zealand       NZ     NZ    NZL       NZL
#
#     ISO_N3 UN_A3 WB_A2 WB_A3
# 129    -99  -099   -99   USA
# 148    292   292   -99   GIB
# 189    500   500   -99   MSR
# 195    660   660   -99   AIA
# 201    654   654   -99   SHN
# 209    833   833    IM   IMY
# 211    086  -099   -99   IOT
# 214    184   184   -99   COK
# 218    090   090    SB   SLB
# 226    570   570   -99   NIU
# 232    -99  -099   -99   FRA
# 234    528   528         BES
# 235    528   528         BES
# 236    528   528         BES
# 237    528   528    NL   NLD
# 238    -99  -099   -99   CCK
# 239    -99  -099   -99   CXR
# 240    581  -099   -99   UMI
# 241    581  -099   -99   UMI
# 242    581  -099   -99   UMI
# 243    581  -099   -99   UMI
# 244    581  -099   -99   UMI
# 245    581  -099   -99   UMI
# 246    581  -099   -99   USA
# 247    581  -099   -99   UMI
# 248    581  -099   -99   UMI
# 249    554   554         TKL
# 250    554   554    NZ   NZL

# %% [markdown]
# Now that we have a simpler map, it would be good to have a column with no repeated values in the ISO codes (that requires some research):

# %%
mapWorld.loc[[234,235,236,249],'ISO_A2']=['BQ','BQ','BQ','TK']
mapWorld.loc[[234,235,236,249],'ISO_A3']=['BQ1','BQ2','BQ3','TKL']
mapWorld.loc[[234,235,236,249],'ISO_A3_EH']=['BQ1','BQ2','BQ3','TKL']

# %% [markdown]
# It seems **WB_NAME** would be the best candidate for unique names. Let's verify:

# %%
mapWorld[mapWorld.duplicated(subset=['WB_NAME'],keep=False)].drop(columns='geometry')
# Out:
# Empty DataFrame
# Columns: [TYPE, FORMAL_EN, WB_NAME, NAME_EN, FIPS_10_, ISO_A2, ISO_A3, ISO_A3_EH, ISO_N3, UN_A3, WB_A2, WB_A3]
# Index: []

# %% [markdown]
# Let's check the missing values:

# %%
# on the missing ISOs?
mapWorld[(mapWorld.loc[:,['ISO_A2','ISO_A3','ISO_A3_EH']].isin(["-99","-099"])).any(axis=1)]
# Out:
#                   TYPE           FORMAL_EN                         WB_NAME  \
# 20             Country     French Republic                          France
# 50   Sovereign country   Kingdom of Norway                          Norway
# 62   Sovereign country  Republic of Kosovo                          Kosovo
# 129              Lease                                 Guantanamo Bay (US)
# 232         Dependency                             Clipperton Island (Fr.)
# 238         Dependency                      Cocos (Keeling) Islands (Aus.)
# 239         Dependency                             Christmas Island (Aus.)
#
#                                  NAME_EN FIPS_10_ ISO_A2 ISO_A3 ISO_A3_EH  \
# 20                                France       FR    -99    -99       FRA
# 50                                Norway      -99    -99    -99       -99
# 62                                Kosovo       KV     XK    -99       -99
# 129            Guantanamo Bay Naval Base      -99    -99    -99       -99
# 232                    Clipperton Island       IP    -99    -99       -99
# 238  Australian Indian Ocean Territories      -99    -99    -99       -99
# 239  Australian Indian Ocean Territories      -99    -99    -99       -99
#
#     ISO_N3 UN_A3 WB_A2 WB_A3  \
# 20     250   250    FR   FRA
# 50     -99   -99   -99   NOR
# 62     -99  -099    KV   KSV
# 129    -99  -099   -99   USA
# 232    -99  -099   -99   FRA
# 238    -99  -099   -99   CCK
# 239    -99  -099   -99   CXR
#
#                                               geometry
# 20   MULTIPOLYGON (((-54.11153 2.11427, -54.07667 2...
# 50   MULTIPOLYGON (((20.62316 69.03636, 20.74440 69...
# 62   POLYGON ((20.06496 42.54676, 20.15260 42.49371...
# 129  MULTIPOLYGON (((-75.09501 19.89723, -75.09495 ...
# 232  POLYGON ((-109.21203 10.30268, -109.22594 10.3...
# 238  MULTIPOLYGON (((96.91391 -12.19451, 96.92107 -...
# 239  POLYGON ((105.70411 -10.43084, 105.65455 -10.4...

# %% [markdown]
# It may call your attention the case of France, Norway and Kosovo.  This is clearly a mistake we need to solve (The Kosovo ISO3 came from [here](https://knowledgecenter.zuora.com/Quick_References/Country%2C_State%2C_and_Province_Codes/A_Country_Names_and_Their_ISO_Codes)):

# %%
mapWorld.loc[[20,50,232,238,239],'ISO_A2']=['FR','NO','CP','CC','CX']
mapWorld.loc[[20,50,62,232,238,239],'ISO_A3']=['FRA','NOR','XKX','CPT','CCK','CXR']
mapWorld.loc[[50,62,232,238,239],'ISO_A3_EH']=['NOR','XKX','CPT','CCK','CXR']

# %% [markdown]
# Let's recheck the repeated ISOs:

# %%
mapWorld[mapWorld.duplicated(subset=['ISO_A3'],keep=False)].drop(columns='geometry')
# Out:
#            TYPE FORMAL_EN              WB_NAME  \
# 240  Dependency            Johnston Atoll (US)
# 241  Dependency             Jarvis Island (US)
# 242  Dependency              Baker Island (US)
# 243  Dependency            Howland Island (US)
# 244  Dependency               Wake Island (US)
# 245  Dependency            Midway Islands (US)
# 246  Dependency            Navassa Island (US)
# 247  Dependency             Palmyra Atoll (US)
# 248  Dependency              Kingman Reef (US)
#
#                                   NAME_EN FIPS_10_ ISO_A2 ISO_A3 ISO_A3_EH  \
# 240  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 241  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 242  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 243  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 244  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 245  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 246  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 247  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 248  United States Minor Outlying Islands      -99     UM    UMI       UMI
#
#     ISO_N3 UN_A3 WB_A2 WB_A3
# 240    581  -099   -99   UMI
# 241    581  -099   -99   UMI
# 242    581  -099   -99   UMI
# 243    581  -099   -99   UMI
# 244    581  -099   -99   UMI
# 245    581  -099   -99   UMI
# 246    581  -099   -99   USA
# 247    581  -099   -99   UMI
# 248    581  -099   -99   UMI

# %% [markdown]
# Notice that what is left are the **UMI**. Are these polygons neighbors?

# %%
mapWorld[mapWorld.ISO_A3.isin(['UMI'])].explore(location=[10, -130],
                                                zoom_start=3,tiles='CartoDB positron',
                                                color='red',style_kwds={'weight':5})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_661400f091706cd22d8dba28a7b4dfbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_661400f091706cd22d8dba28a7b4dfbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_661400f091706cd22d8dba28a7b4dfbc = L.map(
#                 &quot;map_661400f091706cd22d8dba28a7b4dfbc&quot;,
#                 {
#                     center: [10.0, -130.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_661400f091706cd22d8dba28a7b4dfbc);
#
#
#
#
#
#             var tile_layer_4ea317ce134d0eaac097a899a64aa2ab = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_661400f091706cd22d8dba28a7b4dfbc);
#
#
#         function geo_json_79f16e952474c8b51f1525afc2bd51de_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_79f16e952474c8b51f1525afc2bd51de_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_79f16e952474c8b51f1525afc2bd51de_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_79f16e952474c8b51f1525afc2bd51de_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_79f16e952474c8b51f1525afc2bd51de_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_79f16e952474c8b51f1525afc2bd51de.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_79f16e952474c8b51f1525afc2bd51de_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_79f16e952474c8b51f1525afc2bd51de = L.geoJson(null, {
#                 onEachFeature: geo_json_79f16e952474c8b51f1525afc2bd51de_onEachFeature,
#
#                 style: geo_json_79f16e952474c8b51f1525afc2bd51de_styler,
#                 pointToLayer: geo_json_79f16e952474c8b51f1525afc2bd51de_pointToLayer
#         });
#
#         function geo_json_79f16e952474c8b51f1525afc2bd51de_add (data) {
#             geo_json_79f16e952474c8b51f1525afc2bd51de
#                 .addData(data)
#                 .addTo(map_661400f091706cd22d8dba28a7b4dfbc);
#         }
#             geo_json_79f16e952474c8b51f1525afc2bd51de_add({&quot;bbox&quot;: [-177.3807266918833, -0.3887671852573362, 166.65235436286366, 28.214422919082494], &quot;features&quot;: [{&quot;bbox&quot;: [-169.54767818889727, 16.721909897923524, -169.51276607989064, 16.762437241585474], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-169.5416967440095, 16.721909897923524], [-169.52240963429716, 16.732163804216214], [-169.54767818889727, 16.727362372375637], [-169.5416967440095, 16.721909897923524]]], [[[-169.51276607989064, 16.744330144920298], [-169.51366126235735, 16.745591539418058], [-169.51366126235735, 16.743963933788564], [-169.51276607989064, 16.744330144920298]]], [[[-169.5332738915768, 16.75478750214154], [-169.52839108008425, 16.75604889484066], [-169.51740475242735, 16.762437241585474], [-169.53917395681262, 16.7544619808358], [-169.5332738915768, 16.7547875

# %% [markdown]
# This is good they each have a different polygon. If they were neighbors you may try to *glue* them into one geometry, but this is not the case.
#
# We know there are no empty cells, but there might be cells with just one space (or more):

# %%
CellOnlySpaces=lambda x:x.str.match(r'\s+')
where=['TYPE','FORMAL_EN','WB_NAME','NAME_EN']
mapWorld[(mapWorld.loc[:,where].apply(CellOnlySpaces)).any(axis=1)]
# Out:
#                   TYPE FORMAL_EN  \
# 129              Lease
# 148         Dependency
# 189         Dependency
# 195         Dependency
# 201         Dependency
# 209            Country
# 211         Dependency
# 214         Dependency
# 218  Sovereign country
# 226         Dependency
# 232         Dependency
# 238         Dependency
# 239         Dependency
# 240         Dependency
# 241         Dependency
# 242         Dependency
# 243         Dependency
# 244         Dependency
# 245         Dependency
# 246         Dependency
# 247         Dependency
# 248         Dependency
#
#                                                WB_NAME  \
# 129                                Guantanamo Bay (US)
# 148                                     Gibraltar (UK)
# 189                                    Montserrat (UK)
# 195                                      Anguilla (UK)
# 201  Saint Helena, Ascension and Tristan da Cunha (UK)
# 209                                   Isle of Man (UK)
# 211                British Indian Ocean Territory (UK)
# 214                                  Cook Islands (NZ)
# 218                                    Solomon Islands
# 226                                          Niue (NZ)
# 232                            Clipperton Island (Fr.)
# 238                     Cocos (Keeling) Islands (Aus.)
# 239                            Christmas Island (Aus.)
# 240                                Johnston Atoll (US)
# 241                                 Jarvis Island (US)
# 242                                  Baker Island (US)
# 243                                Howland Island (US)
# 244                                   Wake Island (US)
# 245                                Midway Islands (US)
# 246                                Navassa Island (US)
# 247                                 Palmyra Atoll (US)
# 248                                  Kingman Reef (US)
#
#                                   NAME_EN FIPS_10_ ISO_A2 ISO_A3 ISO_A3_EH  \
# 129             Guantanamo Bay Naval Base      -99    -99    -99       -99
# 148                             Gibraltar       GI     GI    GIB       GIB
# 189                            Montserrat       MH     MS    MSR       MSR
# 195                              Anguilla       AV     AI    AIA       AIA
# 201                          Saint Helena       SH     SH    SHN       SHN
# 209                           Isle of Man       IM     IM    IMN       IMN
# 211        British Indian Ocean Territory       IO     IO    IOT       IOT
# 214                          Cook Islands       CW     CK    COK       COK
# 218                       Solomon Islands       BP     SB    SLB       SLB
# 226                                  Niue       NE     NU    NIU       NIU
# 232                     Clipperton Island       IP     CP    CPT       CPT
# 238   Australian Indian Ocean Territories      -99     CC    CCK       CCK
# 239   Australian Indian Ocean Territories      -99     CX    CXR       CXR
# 240  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 241  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 242  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 243  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 244  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 245  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 246  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 247  United States Minor Outlying Islands      -99     UM    UMI       UMI
# 248  United States Minor Outlying Islands      -99     UM    UMI       UMI
#
#     ISO_N3 UN_A3 WB_A2 WB_A3  \
# 129    -99  -099   -99   USA
# 148    292   292   -99   GIB
# 189    500   500   -99   MSR
# 195    660   660   -99   AIA
# 201    654   654   -99   SHN
# 209    833   833    IM   IMY
# 211    086  -099   -99   IOT
# 214    184   184   -99   COK
# 218    090   090    SB   SLB
# 226    570   570   -99   NIU
# 232    -99  -099   -99   FRA
# 238    -99  -099   -99   CCK
# 239    -99  -099   -99   CXR
# 240    581  -099   -99   UMI
# 241    581  -099   -99   UMI
# 242    581  -099   -99   UMI
# 243    581  -099   -99   UMI
# 244    581  -099   -99   UMI
# 245    581  -099   -99   UMI
# 246    581  -099   -99   USA
# 247    581  -099   -99   UMI
# 248    581  -099   -99   UMI
#
#                                               geometry
# 129  MULTIPOLYGON (((-75.09501 19.89723, -75.09495 ...
# 148  POLYGON ((-5.35839 36.14111, -5.35025 36.11929...
# 189  POLYGON ((-62.14737 16.74429, -62.20202 16.819...
# 195  MULTIPOLYGON (((-63.00739 18.27302, -63.16784 ...
# 201  MULTIPOLYGON (((-9.92638 -40.34881, -9.96276 -...
# 209  POLYGON ((-4.61213 54.05695, -4.39078 54.19473...
# 211  MULTIPOLYGON (((72.46754 -7.38388, 72.43287 -7...
# 214  MULTIPOLYGON (((-157.93456 -21.87754, -157.961...
# 218  MULTIPOLYGON (((160.50367 -11.73602, 160.08717...
# 226  POLYGON ((-169.85114 -18.96510, -169.89582 -18...
# 232  POLYGON ((-109.21203 10.30268, -109.22594 10.3...
# 238  MULTIPOLYGON (((96.91391 -12.19451, 96.92107 -...
# 239  POLYGON ((105.70411 -10.43084, 105.65455 -10.4...
# 240  MULTIPOLYGON (((-169.54170 16.72191, -169.5224...
# 241  POLYGON ((-160.02998 -0.37615, -160.02477 -0.3...
# 242  MULTIPOLYGON (((-176.47529 0.19310, -176.47688...
# 243  POLYGON ((-176.63618 0.79019, -176.63610 0.803...
# 244  POLYGON ((166.61940 19.28164, 166.64422 19.275...
# 245  MULTIPOLYGON (((-177.32490 28.20498, -177.3289...
# 246  POLYGON ((-75.02432 18.41726, -75.01781 18.396...
# 247  POLYGON ((-162.06086 5.88719, -162.07136 5.890...
# 248  POLYGON ((-162.40018 6.44514, -162.40018 6.430...

# %% [markdown]
# We have a column that could be used to replace those values:

# %%
mapWorld.loc[worldmap.FORMAL_EN.str.match(r'\s+'),'WB_NAME']
# Out:
# 129                                  Guantanamo Bay (US)
# 148                                       Gibraltar (UK)
# 189                                      Montserrat (UK)
# 195                                        Anguilla (UK)
# 201    Saint Helena, Ascension and Tristan da Cunha (UK)
# 209                                     Isle of Man (UK)
# 211                  British Indian Ocean Territory (UK)
# 214                                    Cook Islands (NZ)
# 218                                      Solomon Islands
# 226                                            Niue (NZ)
# 232                              Clipperton Island (Fr.)
# 238                       Cocos (Keeling) Islands (Aus.)
# 239                              Christmas Island (Aus.)
# 240                                  Johnston Atoll (US)
# 241                                   Jarvis Island (US)
# 242                                    Baker Island (US)
# 243                                  Howland Island (US)
# 244                                     Wake Island (US)
# 245                                  Midway Islands (US)
# 246                                  Navassa Island (US)
# 247                                   Palmyra Atoll (US)
# 248                                    Kingman Reef (US)
# Name: WB_NAME, dtype: object

# %% [markdown]
# We can complete those cells with:

# %%
# getting rid of any text \w+. within parentheses \(\), with one space before, and possibly one after
mapWorld.loc[worldmap.FORMAL_EN.str.match(r'\s+'),'WB_NAME'].str.replace('\s\(\w+.\)\s*',"",regex=True)
# Out:
# 129                                  Guantanamo Bay
# 148                                       Gibraltar
# 189                                      Montserrat
# 195                                        Anguilla
# 201    Saint Helena, Ascension and Tristan da Cunha
# 209                                     Isle of Man
# 211                  British Indian Ocean Territory
# 214                                    Cook Islands
# 218                                 Solomon Islands
# 226                                            Niue
# 232                               Clipperton Island
# 238                                    CocosIslands
# 239                                Christmas Island
# 240                                  Johnston Atoll
# 241                                   Jarvis Island
# 242                                    Baker Island
# 243                                  Howland Island
# 244                                     Wake Island
# 245                                  Midway Islands
# 246                                  Navassa Island
# 247                                   Palmyra Atoll
# 248                                    Kingman Reef
# Name: WB_NAME, dtype: object

# %%
# then,
newNames=mapWorld.loc[worldmap.FORMAL_EN.str.match(r'\s+'),'WB_NAME'].str.replace('\s\(\w+.\)\s*',"",regex=True)
mapWorld.loc[worldmap.FORMAL_EN.str.match(r'\s+'),'FORMAL_EN']=newNames

# %%
# confirming
mapWorld[(mapWorld.loc[:,where].apply(CellOnlySpaces)).any(axis=1)]
# Out:
# Empty GeoDataFrame
# Columns: [TYPE, FORMAL_EN, WB_NAME, NAME_EN, FIPS_10_, ISO_A2, ISO_A3, ISO_A3_EH, ISO_N3, UN_A3, WB_A2, WB_A3, geometry]
# Index: []

# %% [markdown]
# ### Checking validity of geometries
#
# The way the geometry has been assembled might result in some serious problem if not solved before the analysis. Let's check if we have invalid geometry:

# %%
mapWorld[~mapWorld.is_valid]
# Out:
#                   TYPE FORMAL_EN WB_NAME NAME_EN FIPS_10_ ISO_A2 ISO_A3  \
# 174  Sovereign country     Japan   Japan   Japan       JA     JP    JPN
#
#     ISO_A3_EH ISO_N3 UN_A3 WB_A2 WB_A3  \
# 174       JPN    392   392    JP   JPN
#
#                                               geometry
# 174  MULTIPOLYGON (((129.78321 31.79963, 129.65937 ...

# %% [markdown]
# We can plot the invalid geometry:

# %%
mapWorld[~mapWorld.is_valid].plot()
# Out:
# <Axes: >
# Executing shutdown due to inactivity...
# 2023-03-20 11:13:18,455 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2023-03-20 11:13:18,673 - INFO     - Executing shutdown...
# Exception on /shutdown [GET]
# Traceback (most recent call last):
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/dtale/app.py", line 435, in shutdown
#     shutdown_server()
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/dtale/app.py", line 421, in shutdown_server
#     raise RuntimeError("Not running with the Werkzeug Server")
# RuntimeError: Not running with the Werkzeug Server
# 2023-03-20 11:13:18,674 - ERROR    - Exception on /shutdown [GET]
# Traceback (most recent call last):
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/dtale/app.py", line 435, in shutdown
#     shutdown_server()
#   File "/Users/JoseManuel/opt/anaconda3/envs/Spatial_DS_3_11/lib/python3.11/site-packages/dtale/app.py", line 421, in shutdown_server
#     raise RuntimeError("Not running with the Werkzeug Server")
# RuntimeError: Not running with the Werkzeug Server

# %% [markdown]
# It is difficul to see what is wrong. Let's get some information:

# %%
from shapely.validation import explain_validity, make_valid

explain_validity(mapWorld[~mapWorld.is_valid].geometry)
# Out:
# 174    Hole lies outside shell[144.448252799927 43.94...
# Name: geometry, dtype: object

# %% [markdown]
# We can solve the problem without actually seeing what is going on:

# %%
# solving the issue:
mapWorld.loc[174,'geometry']=make_valid(mapWorld.loc[174,'geometry'])

# %%
# what's invalid?
mapWorld[~mapWorld.is_valid]
# Out:
# Empty GeoDataFrame
# Columns: [TYPE, FORMAL_EN, WB_NAME, NAME_EN, FIPS_10_, ISO_A2, ISO_A3, ISO_A3_EH, ISO_N3, UN_A3, WB_A2, WB_A3, geometry]
# Index: []

# %% [markdown]
# Let's save the file:

# %%
mapWorld.to_file(os.path.join("maps","mapWorld.gpkg"), layer='countries', driver="GPKG")

# %% [markdown]
# However, it would be good to actually see what was invalid, and what the solution was.
