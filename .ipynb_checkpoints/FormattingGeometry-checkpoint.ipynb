# %% [markdown]
# # Formatting Data (geometry)
#
#
# In general, you need to format geometry when you get coordinates.

# %%
import geopandas as gpd

theMapFile="https://github.com/CienciaDeDatosEspacial/mapFiles/raw/main/MapSeattle.geojson"
seattleMap=gpd.read_file(theMapFile)

# %%
type(seattleMap)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
seattleMap.plot()
# Out:
# <Axes: >

# %%
seattleMap.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
seattleMap.crs.to_epsg()
# Out:
# 4326

# %%
seattleMap.total_bounds
# Out:
# array([-122.43595826,   47.4955679 , -122.23592105,   47.7341467 ])

# %%
seattleMapBorder=seattleMap.dissolve()
seattleMapBorder.plot()
# Out:
# <Axes: >

# %%
seattleMapBorder.length
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_41452/1787288604.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   seattleMapBorder.length
# 0    2.21871
# dtype: float64

# %%
seattleMapBorder.to_crs(6597).length
# Out:
# 0    658860.295159
# dtype: float64

# %%
seattleMapBorder.to_crs(2285).area
# Out:
# 0    2.319869e+09
# dtype: float64

# %%
seattleMapBorder.to_crs(2285).crs
# Out:
# <Derived Projected CRS: EPSG:2285>
# Name: NAD83 / Washington North (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - Washington - counties of Chelan; Clallam; Douglas; Ferry; Grant north of approximately 47°30'N; Island; Jefferson; King; Kitsap; Lincoln; Okanogan; Pend Oreille; San Juan; Skagit; Snohomish; Spokane; Stevens; Whatcom.
# - bounds: (-124.79, 47.08, -117.02, 49.05)
# Coordinate Operation:
# - name: SPCS83 Washington North zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
seattleMapBorder.to_crs(2285).plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import os

where=os.path.join('data','calls911.pkl')
calls911=pd.read_pickle(where)
calls911.head()
# Out:
#               address             type            datetime   latitude  \
# 0  14100 Linden Ave N   Medic Response 2023-03-13 01:08:00   47.73104
# 1    4915 25th Ave Ne     Aid Response 2023-03-13 01:01:00  47.664451
# 2  106 Bellevue Ave E   Medic Response 2023-03-13 00:55:00  47.618676
# 3    800 Jefferson St  Auto Fire Alarm 2023-03-13 00:52:00  47.604377
# 4         700 3RD AVE     Aid Response 2023-03-13 00:51:00  47.603484
#
#      longitude                                    report_location  \
# 0  -122.347764  {'type': 'Point', 'coordinates': [-122.347764,...
# 1  -122.300909  {'type': 'Point', 'coordinates': [-122.300909,...
# 2  -122.326727  {'type': 'Point', 'coordinates': [-122.326727,...
# 3  -122.325207  {'type': 'Point', 'coordinates': [-122.325207,...
# 4  -122.332062  {'type': 'Point', 'coordinates': [-122.332062,...
#
#   incident_number        date  year  month month_name  day weekday  hour  \
# 0      F230030840  2023-03-13  2023      3      March   13  Monday     1
# 1      F230030839  2023-03-13  2023      3      March   13  Monday     1
# 2      F230030838  2023-03-13  2023      3      March   13  Monday     0
# 3      F230030837  2023-03-13  2023      3      March   13  Monday     0
# 4      F230030836  2023-03-13  2023      3      March   13  Monday     0
#
#    minute  nightTime
# 0       8       True
# 1       1       True
# 2      55       True
# 3      52       True
# 4      51       True

# %%
calls911=calls911[~calls911['report_location'].isna()]

# %%
import pandas as pd
from shapely.geometry import Point

calls911['geometry']=gpd.GeoSeries([Point(point['coordinates']) for point in calls911['report_location']],
                                   crs="EPSG:4326")

# %%
calls911_sp = gpd.GeoDataFrame(calls911, geometry='geometry')

# %%
calls911_sp.plot()
# Out:
# <Axes: >

# %%
calls911_sp.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# You know the call identify the location of the incident. Then you are interested in representing that coordinates in a map. You have this map:

# %%
import geopandas as gpd

theMapFile=os.path.join("DataFiles","MapSeattle.geojson")
seattleMap=gpd.read_file(theMapFile)
seattleMap.plot()

# %% [markdown]
# The map came from a geojson file. It is a common format these days. However, the more familiar format has always been the shapefile (**.shp**)
#
# All maps are a **projection** of our 3D world. So, maps, 2D objects, should let us know that:

# %%
# projection info is not here!!
seattleMap.info()

# %%
# it is here
seattleMap.crs

# %% [markdown]
# The **report_location** column came from the original data in the _API_; it has the coordinates of the event, and it is very useful. I can recover that in Python as it is a dictionary.

# %%
[x['coordinates'] for x in calls911.report_location[1:10]]

# %% [markdown]
# Fortunately, we have already that information in the columns _longitude_ and _latitude_; so we can drop it:

# %%
calls911.drop(columns=["report_location"],inplace=True)

# %% [markdown]
# However, _longitude_ and _latitude_ are not numeric, then we need to format:

# %%
calls911[['longitude','latitude']]=calls911[['longitude','latitude']].apply(lambda x:pd.to_numeric(x))

# %% [markdown]
# Let's pay plot the coordinates:

# %%
calls911.plot.scatter(x = 'longitude', y = 'latitude')

# %% [markdown]
# Now, let's plot the coordinates on top of the map:

# %%
import matplotlib.pyplot as plt
ax = seattleMapBorder.plot(color='white',
                  edgecolor='black')

calls911_sp.plot(ax=ax, color='red',markersize=0.5)

plt.show()

# %% [markdown]
# It fails as it is not a spatial data frame.
#
# The next step is to create a spatial dataframe for the 911 data. Let's use geopandas:

# %%
import geopandas as gpd

pointsAsGeometry=gpd.points_from_xy(calls911.longitude,
                                    calls911.latitude,crs="EPSG:4326")

calls911_geo = gpd.GeoDataFrame(calls911,
                                geometry=pointsAsGeometry)

# check:

calls911_geo.crs

# %% [markdown]
# Let's redo the previous _failed_ plot:

# %%
ax = seattleMap.plot(color='white',
                  edgecolor='black')

calls911_geo.plot(ax=ax, color='red',
                  markersize=0.5)
plt.show()

# %% [markdown]
# Notice there is an event registered which is not in Seattle.

# %%
calls911_geo[calls911_geo.longitude==calls911_geo.longitude.max()]

# %% [markdown]
# The map of Seattle has information of its limits: the **bounding box**. You can use that to filter the events:

# %%
calls911_geoclipped = gpd.clip(gdf=calls911_geo,
                               mask=seattleMap)

###

ax = seattleMap.plot(color='white',
                  edgecolor='black')

calls911_geoclipped.plot(ax=ax, color='red',
                  markersize=0.5)
plt.show()

# %% [markdown]
# We could save this file as an spatial data frame for further use in another program:

# %%
# the datetime format can not be saved so we drop it.
# other choice could be to save it as a string.

whereGeo=os.path.join("DataFiles","calls911_geo.geojson")

calls911_geoclipped.drop(columns=["date"]).to_file(whereGeo,
                                            driver='GeoJSON')
